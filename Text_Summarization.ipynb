# %% [markdown]
# <a href="https://colab.research.google.com/github/bahgat-ahmed/Text-summarizations/blob/master/Text_Summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# I was following this [Youtube Tutorial](https://www.youtube.com/watch?v=9PoKellNrBc).

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# The following text is from this [Wikipedia Page](https://en.wikipedia.org/wiki/Automatic_summarization).

# %%
text = """
Automatic summarization
From Wikipedia, the free encyclopedia
Jump to navigationJump to search

This article has multiple issues. Please help improve it or discuss these issues on the talk page. (Learn how and when to remove these template messages)
This article includes a list of references, but its sources remain unclear because it has insufficient inline citations. (March 2015)
This article's tone or style may not reflect the encyclopedic tone used on Wikipedia. (March 2015)
Automatic summarization is the process of shortening a set of data computationally, to create a subset (a summary) that represents the most important or relevant information within the original content.

In addition to text, images and videos can also be summarized. Text summarization finds the most informative sentences in a document[1]; image summarization finds the most representative images within an image collection[citation needed]; video summarization extracts the most important frames from the video content.[2]

Approaches
There are two general approaches to automatic summarization: extraction and abstraction.

Extraction-based summarization
Here, content is extracted from the original data, but the extracted content is not modified in any way. Examples of extracted content include key-phrases that can be used to "tag" or index a text document, or key sentences (including headings) that collectively comprise an abstract, and representative images or video segments, as stated above. For text, extraction is analogous to the process of skimming, where the summary (if available), headings and subheadings, figures, the first and last paragraphs of a section, and optionally the first and last sentences in a paragraph are read before one chooses to read the entire document in detail.[3]

Abstraction-based summarization
This has been applied mainly for text. Abstractive methods build an internal semantic representation of the original content, and then use this representation to create a summary that is closer to what a human might express. Abstraction may transform the extracted content by paraphrasing sections of the source document, to condense a text more strongly than extraction. Such transformation, however, is computationally much more challenging than extraction, involving both natural language processing and often a deep understanding of the domain of the original text in cases where the original document relates to a special field of knowledge. "Paraphrasing" is even more difficult to apply to image and video, which is why most summarization systems are extractive.

Aided summarization
Approaches aimed at higher summarization quality rely on combined software and human effort. In Machine Aided Human Summarization, extractive techniques highlight candidate passages for inclusion (to which the human adds or removes text). In Human Aided Machine Summarization, a human post-processes software output, in the same way that one edits the output of automatic translation by Google Translate.

Applications and systems for summarization
There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on. The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.). The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query. Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.

An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document. Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic). This problem is called multi-document summarization. A related application is summarizing news articles. Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.

Image collection summarization is another application example of automatic summarization. It consists in selecting a representative set of images from a larger set of images.[4] A summary in this context is useful to show the most representative images of results in an image collection exploration system. Video summarization is a related domain, where the system automatically creates a trailer of a long video. This also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions. Similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured.

At a very high level, summarization algorithms try to find subsets of objects (like set of sentences, or a set of images), which cover information of the entire set. This is also called the core-set. These algorithms model notions like diversity, coverage, information and representativeness of the summary. Query based summarization techniques, additionally model for relevance of the summary with the query. Some techniques and algorithms which naturally model summarization problems are TextRank and PageRank, Submodular set function, Determinantal point process, maximal marginal relevance (MMR) etc.

Keyphrase extraction
The task is the following. You are given a piece of text, such as a journal article, and you must produce a list of keywords or key[phrase]s that capture the primary topics discussed in the text.[5] In the case of research articles, many authors provide manually assigned keywords, but most text lacks pre-existing keyphrases. For example, news articles rarely have keyphrases attached, but it would be useful to be able to automatically do so for a number of applications discussed below. Consider the example text from a news article:

"The Army Corps of Engineers, rushing to meet President Bush's promise to protect New Orleans by the start of the 2006 hurricane season, installed defective flood-control pumps last year despite warnings from its own expert that the equipment would fail during a storm, according to documents obtained by The Associated Press".
A keyphrase extractor might select "Army Corps of Engineers", "President Bush", "New Orleans", and "defective flood-control pumps" as keyphrases. These are pulled directly from the text. In contrast, an abstractive keyphrase system would somehow internalize the content and generate keyphrases that do not appear in the text, but more closely resemble what a human might produce, such as "political negligence" or "inadequate protection from floods". Abstraction requires a deep understanding of the text, which makes it difficult for a computer system. Keyphrases have many applications. They can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.

Depending on the different literature and the definition of key terms, words or phrases, keyword extraction is a highly related theme.

Supervised learning approaches
Beginning with the work of Turney,[6] many researchers have approached keyphrase extraction as a supervised machine learning problem. Given a document, we construct an example for each unigram, bigram, and trigram found in the text (though other text units are also possible, as discussed below). We then compute various features describing each example (e.g., does the phrase begin with an upper-case letter?). We assume there are known keyphrases available for a set of training documents. Using the known keyphrases, we can assign positive or negative labels to the examples. Then we learn a classifier that can discriminate between positive and negative examples as a function of the features. Some classifiers make a binary classification for a test example, while others assign a probability of being a keyphrase. For instance, in the above text, we might learn a rule that says phrases with initial capital letters are likely to be keyphrases. After training a learner, we can select keyphrases for test documents in the following manner. We apply the same example-generation strategy to the test documents, then run each example through the learner. We can determine the keyphrases by looking at binary classification decisions or probabilities returned from our learned model. If probabilities are given, a threshold is used to select the keyphrases. Keyphrase extractors are generally evaluated using precision and recall. Precision measures how many of the proposed keyphrases are actually correct. Recall measures how many of the true keyphrases your system proposed. The two measures can be combined in an F-score, which is the harmonic mean of the two (F = 2PR/(P + R) ). Matches between the proposed keyphrases and the known keyphrases can be checked after stemming or applying some other text normalization.

Designing a supervised keyphrase extraction system involves deciding on several choices (some of these apply to unsupervised, too). The first choice is exactly how to generate examples. Turney and others have used all possible unigrams, bigrams, and trigrams without intervening punctuation and after removing stopwords. Hulth showed that you can get some improvement by selecting examples to be sequences of tokens that match certain patterns of part-of-speech tags. Ideally, the mechanism for generating examples produces all the known labeled keyphrases as candidates, though this is often not the case. For example, if we use only unigrams, bigrams, and trigrams, then we will never be able to extract a known keyphrase containing four words. Thus, recall may suffer. However, generating too many examples can also lead to low precision.

We also need to create features that describe the examples and are informative enough to allow a learning algorithm to discriminate keyphrases from non- keyphrases. Typically features involve various term frequencies (how many times a phrase appears in the current text or in a larger corpus), the length of the example, relative position of the first occurrence, various boolean syntactic features (e.g., contains all caps), etc. The Turney paper used about 12 such features. Hulth uses a reduced set of features, which were found most successful in the KEA (Keyphrase Extraction Algorithm) work derived from Turney’s seminal paper.

In the end, the system will need to return a list of keyphrases for a test document, so we need to have a way to limit the number. Ensemble methods (i.e., using votes from several classifiers) have been used to produce numeric scores that can be thresholded to provide a user-provided number of keyphrases. This is the technique used by Turney with C4.5 decision trees. Hulth used a single binary classifier so the learning algorithm implicitly determines the appropriate number.

Once examples and features are created, we need a way to learn to predict keyphrases. Virtually any supervised learning algorithm could be used, such as decision trees, Naive Bayes, and rule induction. In the case of Turney's GenEx algorithm, a genetic algorithm is used to learn parameters for a domain-specific keyphrase extraction algorithm. The extractor follows a series of heuristics to identify keyphrases. The genetic algorithm optimizes parameters for these heuristics with respect to performance on training documents with known key phrases.

Unsupervised approach: TextRank
Another keyphrase extraction algorithm is TextRank. While supervised methods have some nice properties, like being able to produce interpretable rules for what features characterize a keyphrase, they also require a large amount of training data. Many documents with known keyphrases are needed. Furthermore, training on a specific domain tends to customize the extraction process to that domain, so the resulting classifier is not necessarily portable, as some of Turney's results demonstrate. Unsupervised keyphrase extraction removes the need for training data. It approaches the problem from a different angle. Instead of trying to learn explicit features that characterize keyphrases, the TextRank algorithm[7] exploits the structure of the text itself to determine keyphrases that appear "central" to the text in the same way that PageRank selects important Web pages. Recall this is based on the notion of "prestige" or "recommendation" from social networks. In this way, TextRank does not rely on any previous training data at all, but rather can be run on any arbitrary piece of text, and it can produce output simply based on the text's intrinsic properties. Thus the algorithm is easily portable to new domains and languages.

TextRank is a general purpose graph-based ranking algorithm for NLP. Essentially, it runs PageRank on a graph specially designed for a particular NLP task. For keyphrase extraction, it builds a graph using some set of text units as vertices. Edges are based on some measure of semantic or lexical similarity between the text unit vertices. Unlike PageRank, the edges are typically undirected and can be weighted to reflect a degree of similarity. Once the graph is constructed, it is used to form a stochastic matrix, combined with a damping factor (as in the "random surfer model"), and the ranking over vertices is obtained by finding the eigenvector corresponding to eigenvalue 1 (i.e., the stationary distribution of the random walk on the graph).

The vertices should correspond to what we want to rank. Potentially, we could do something similar to the supervised methods and create a vertex for each unigram, bigram, trigram, etc. However, to keep the graph small, the authors decide to rank individual unigrams in a first step, and then include a second step that merges highly ranked adjacent unigrams to form multi-word phrases. This has a nice side effect of allowing us to produce keyphrases of arbitrary length. For example, if we rank unigrams and find that "advanced", "natural", "language", and "processing" all get high ranks, then we would look at the original text and see that these words appear consecutively and create a final keyphrase using all four together. Note that the unigrams placed in the graph can be filtered by part of speech. The authors found that adjectives and nouns were the best to include. Thus, some linguistic knowledge comes into play in this step.

Edges are created based on word co-occurrence in this application of TextRank. Two vertices are connected by an edge if the unigrams appear within a window of size N in the original text. N is typically around 2–10. Thus, "natural" and "language" might be linked in a text about NLP. "Natural" and "processing" would also be linked because they would both appear in the same string of N words. These edges build on the notion of "text cohesion" and the idea that words that appear near each other are likely related in a meaningful way and "recommend" each other to the reader.

Since this method simply ranks the individual vertices, we need a way to threshold or produce a limited number of keyphrases. The technique chosen is to set a count T to be a user-specified fraction of the total number of vertices in the graph. Then the top T vertices/unigrams are selected based on their stationary probabilities. A post- processing step is then applied to merge adjacent instances of these T unigrams. As a result, potentially more or less than T final keyphrases will be produced, but the number should be roughly proportional to the length of the original text.

It is not initially clear why applying PageRank to a co-occurrence graph would produce useful keyphrases. One way to think about it is the following. A word that appears multiple times throughout a text may have many different co-occurring neighbors. For example, in a text about machine learning, the unigram "learning" might co-occur with "machine", "supervised", "un-supervised", and "semi-supervised" in four different sentences. Thus, the "learning" vertex would be a central "hub" that connects to these other modifying words. Running PageRank/TextRank on the graph is likely to rank "learning" highly. Similarly, if the text contains the phrase "supervised classification", then there would be an edge between "supervised" and "classification". If "classification" appears several other places and thus has many neighbors, its importance would contribute to the importance of "supervised". If it ends up with a high rank, it will be selected as one of the top T unigrams, along with "learning" and probably "classification". In the final post-processing step, we would then end up with keyphrases "supervised learning" and "supervised classification".

In short, the co-occurrence graph will contain densely connected regions for terms that appear often and in different contexts. A random walk on this graph will have a stationary distribution that assigns large probabilities to the terms in the centers of the clusters. This is similar to densely connected Web pages getting ranked highly by PageRank. This approach has also been used in document summarization, considered below.

Document summarization
Like keyphrase extraction, document summarization aims to identify the essence of a text. The only real difference is that now we are dealing with larger text units—whole sentences instead of words and phrases.

Before getting into the details of some summarization methods, we will mention how summarization systems are typically evaluated. The most common way is using the so-called ROUGE (Recall-Oriented Understudy for Gisting Evaluation) measure. This is a recall-based measure that determines how well a system-generated summary covers the content present in one or more human-generated model summaries known as references. It is recall-based to encourage systems to include all the important topics in the text. Recall can be computed with respect to unigram, bigram, trigram, or 4-gram matching. For example, ROUGE-1 is computed as division of count of unigrams in reference that appear in system and count of unigrams in reference summary.

If there are multiple references, the ROUGE-1 scores are averaged. Because ROUGE is based only on content overlap, it can determine if the same general concepts are discussed between an automatic summary and a reference summary, but it cannot determine if the result is coherent or the sentences flow together in a sensible manner. High-order n-gram ROUGE measures try to judge fluency to some degree. Note that ROUGE is similar to the BLEU measure for machine translation, but BLEU is precision- based, because translation systems favor accuracy.

A promising line in document summarization is adaptive document/text summarization.[8] The idea of adaptive summarization involves preliminary recognition of document/text genre and subsequent application of summarization algorithms optimized for this genre. First summarizes that perform adaptive summarization have been created.[9]

Supervised learning approaches
Supervised text summarization is very much like supervised keyphrase extraction. Basically, if you have a collection of documents and human-generated summaries for them, you can learn features of sentences that make them good candidates for inclusion in the summary. Features might include the position in the document (i.e., the first few sentences are probably important), the number of words in the sentence, etc. The main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary". This is not typically how people create summaries, so simply using journal abstracts or existing summaries is usually not sufficient. The sentences in these summaries do not necessarily match up with sentences in the original text, so it would be difficult to assign labels to examples for training. Note, however, that these natural summaries can still be used for evaluation purposes, since ROUGE-1 only cares about unigrams.

Maximum entropy-based summarization
During the DUC 2001 and 2002 evaluation workshops, TNO developed a sentence extraction system for multi-document summarization in the news domain. The system was based on a hybrid system using a naive Bayes classifier and statistical language models for modeling salience. Although the system exhibited good results, the researchers wanted to explore the effectiveness of a maximum entropy (ME) classifier for the meeting summarization task, as ME is known to be robust against feature dependencies. Maximum entropy has also been applied successfully for summarization in the broadcast news domain.

TextRank and LexRank
The unsupervised approach to summarization is also quite similar in spirit to unsupervised keyphrase extraction and gets around the issue of costly training data. Some unsupervised summarization approaches are based on finding a "centroid" sentence, which is the mean word vector of all the sentences in the document. Then the sentences can be ranked with regard to their similarity to this centroid sentence.

A more principled way to estimate sentence importance is using random walks and eigenvector centrality. LexRank[10] is an algorithm essentially identical to TextRank, and both use this approach for document summarization. The two methods were developed by different groups at the same time, and LexRank simply focused on summarization, but could just as easily be used for keyphrase extraction or any other NLP ranking task.

In both LexRank and TextRank, a graph is constructed by creating a vertex for each sentence in the document.

The edges between sentences are based on some form of semantic similarity or content overlap. While LexRank uses cosine similarity of TF-IDF vectors, TextRank uses a very similar measure based on the number of words two sentences have in common (normalized by the sentences' lengths). The LexRank paper explored using unweighted edges after applying a threshold to the cosine values, but also experimented with using edges with weights equal to the similarity score. TextRank uses continuous similarity scores as weights.

In both algorithms, the sentences are ranked by applying PageRank to the resulting graph. A summary is formed by combining the top ranking sentences, using a threshold or length cutoff to limit the size of the summary.

It is worth noting that TextRank was applied to summarization exactly as described here, while LexRank was used as part of a larger summarization system (MEAD) that combines the LexRank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights. In this case, some training documents might be needed, though the TextRank results show the additional features are not absolutely necessary.

Another important distinction is that TextRank was used for single document summarization, while LexRank has been applied to multi-document summarization. The task remains the same in both cases—only the number of sentences to choose from has grown. However, when summarizing multiple documents, there is a greater risk of selecting duplicate or highly redundant sentences to place in the same summary. Imagine you have a cluster of news articles on a particular event, and you want to produce one summary. Each article is likely to have many similar sentences, and you would only want to include distinct ideas in the summary. To address this issue, LexRank applies a heuristic post-processing step that builds up a summary by adding sentences in rank order, but discards any sentences that are too similar to ones already placed in the summary. The method used is called Cross-Sentence Information Subsumption (CSIS).

These methods work based on the idea that sentences "recommend" other similar sentences to the reader. Thus, if one sentence is very similar to many others, it will likely be a sentence of great importance. The importance of this sentence also stems from the importance of the sentences "recommending" it. Thus, to get ranked highly and placed in a summary, a sentence must be similar to many sentences that are in turn also similar to many other sentences. This makes intuitive sense and allows the algorithms to be applied to any arbitrary new text. The methods are domain-independent and easily portable. One could imagine the features indicating important sentences in the news domain might vary considerably from the biomedical domain. However, the unsupervised "recommendation"-based approach applies to any domain.

Multi-document summarization
Main article: Multi-document summarization
Multi-document summarization is an automatic procedure aimed at extraction of information from multiple texts written about the same topic. Resulting summary report allows individual users, such as professional information consumers, to quickly familiarize themselves with information contained in a large cluster of documents. In such a way, multi-document summarization systems are complementing the news aggregators performing the next step down the road of coping with information overload. Multi-document summarization may also be done in response to a question.[11]

Multi-document summarization creates information reports that are both concise and comprehensive. With different opinions being put together and outlined, every topic is described from multiple perspectives within a single document. While the goal of a brief summary is to simplify information search and cut the time by pointing to the most relevant source documents, comprehensive multi-document summary should itself contain the required information, hence limiting the need for accessing original files to cases when refinement is required. Automatic summaries present information extracted from multiple sources algorithmically, without any editorial touch or subjective human intervention, thus making it completely unbiased.[dubious – discuss]

Incorporating diversity
Multi-document extractive summarization faces a problem of potential redundancy. Ideally, we would like to extract sentences that are both "central" (i.e., contain the main ideas) and "diverse" (i.e., they differ from one another). LexRank deals with diversity as a heuristic final stage using CSIS, and other systems have used similar methods, such as Maximal Marginal Relevance (MMR),[12] in trying to eliminate redundancy in information retrieval results. There is a general purpose graph-based ranking algorithm like Page/Lex/TextRank that handles both "centrality" and "diversity" in a unified mathematical framework based on absorbing Markov chain random walks. (An absorbing random walk is like a standard random walk, except some states are now absorbing states that act as "black holes" that cause the walk to end abruptly at that state.) The algorithm is called GRASSHOPPER.[13] In addition to explicitly promoting diversity during the ranking process, GRASSHOPPER incorporates a prior ranking (based on sentence position in the case of summarization).

The state of the art results for multi-document summarization, however, are obtained using mixtures of submodular functions. These methods have achieved the state of the art results for Document Summarization Corpora, DUC 04 - 07.[14] Similar results were also achieved with the use of determinantal point processes (which are a special case of submodular functions) for DUC-04.[15]

A new method for multi-lingual multi-document summarization that avoids redundancy works by simplifying and generating ideograms that represent the meaning of each sentence in each document and then evaluates similarity "qualitatively" by comparing the shape and position of said ideograms has recently been developed. This tool does not use word frequency, does not need training or preprocessing of any kind and works by generating ideograms that represent the meaning of each sentence and then summarizes using two user-supplied parameters: equivalence (when are two sentences to be considered equivalent) and relevance (how long is the desired summary).

Submodular functions as generic tools for summarization
The idea of a submodular set function has recently emerged as a powerful modeling tool for various summarization problems. Submodular functions naturally model notions of coverage, information, representation and diversity. Moreover, several important combinatorial optimization problems occur as special instances of submodular optimization. For example, the set cover problem is a special case of submodular optimization, since the set cover function is submodular. The set cover function attempts to find a subset of objects which cover a given set of concepts. For example, in document summarization, one would like the summary to cover all important and relevant concepts in the document. This is an instance of set cover. Similarly, the facility location problem is a special case of submodular functions. The Facility Location function also naturally models coverage and diversity. Another example of a submodular optimization problem is using a determinantal point process to model diversity. Similarly, the Maximum-Marginal-Relevance procedure can also be seen as an instance of submodular optimization. All these important models encouraging coverage, diversity and information are all submodular. Moreover, submodular functions can be efficiently combined together, and the resulting function is still submodular. Hence, one could combine one submodular function which models diversity, another one which models coverage and use human supervision to learn a right model of a submodular function for the problem.

While submodular functions are fitting problems for summarization, they also admit very efficient algorithms for optimization. For example, a simple greedy algorithm admits a constant factor guarantee.[16] Moreover, the greedy algorithm is extremely simple to implement and can scale to large datasets, which is very important for summarization problems.

Submodular functions have achieved state-of-the-art for almost all summarization problems. For example, work by Lin and Bilmes, 2012[17] shows that submodular functions achieve the best results to date on DUC-04, DUC-05, DUC-06 and DUC-07 systems for document summarization. Similarly, work by Lin and Bilmes, 2011,[18] shows that many existing systems for automatic summarization are instances of submodular functions. This was a breakthrough result establishing submodular functions as the right models for summarization problems.[citation needed]

Submodular Functions have also been used for other summarization tasks. Tschiatschek et al., 2014 show[19] that mixtures of submodular functions achieve state-of-the-art results for image collection summarization. Similarly, Bairi et al., 2015[20] show the utility of submodular functions for summarizing multi-document topic hierarchies. Submodular Functions have also successfully been used for summarizing machine learning datasets.[21]

Applications
[icon]	
This section needs expansion. You can help by adding to it. (February 2017)
Specific applications of automatic summarization include:

The Reddit bot "autotldr",[22] created in 2011 summarizes news articles in the comment-section of reddit posts. It was found to be very useful by the reddit community which upvoted its summaries hundreds of thousands of times.[23] The name is reference to TL;DR − Internet slang for "too long; didn't read".[24][25]
Evaluation techniques
The most common way to evaluate the informativeness of automatic summaries is to compare them with human-made model summaries.

Evaluation techniques fall into intrinsic and extrinsic,[26] inter-textual and intra-textual.[27]

Intrinsic and extrinsic evaluation
An intrinsic evaluation tests the summarization system in and of itself while an extrinsic evaluation tests the summarization based on how it affects the completion of some other task. Intrinsic evaluations have assessed mainly the coherence and informativeness of summaries. Extrinsic evaluations, on the other hand, have tested the impact of summarization on tasks like relevance assessment, reading comprehension, etc.

Inter-textual and intra-textual
Intra-textual methods assess the output of a specific summarization system, and the inter-textual ones focus on contrastive analysis of outputs of several summarization systems.

Human judgement often has wide variance on what is considered a "good" summary, which means that making the evaluation process automatic is particularly difficult. Manual evaluation can be used, but this is both time and labor-intensive as it requires humans to read not only the summaries but also the source documents. Other issues are those concerning coherence and coverage.

One of the metrics used in NIST's annual Document Understanding Conferences, in which research groups submit their systems for both summarization and translation tasks, is the ROUGE metric (Recall-Oriented Understudy for Gisting Evaluation [2]). It essentially calculates n-gram overlaps between automatically generated summaries and previously-written human summaries. A high level of overlap should indicate a high level of shared concepts between the two summaries. Note that overlap metrics like this are unable to provide any feedback on a summary's coherence. Anaphor resolution remains another problem yet to be fully solved. Similarly, for image summarization, Tschiatschek et al., developed a Visual-ROUGE score which judges the performance of algorithms for image summarization.[28]

Domain specific versus domain independent summarization techniques
Domain independent summarization techniques generally apply sets of general features which can be used to identify information-rich text segments. Recent research focus has drifted to domain-specific summarization techniques that utilize the available knowledge specific to the domain of text. For example, automatic summarization research on medical text generally attempts to utilize the various sources of codified medical knowledge and ontologies.[29]

Evaluating summaries qualitatively
The main drawback of the evaluation systems existing so far is that we need at least one reference summary, and for some methods more than one, to be able to compare automatic summaries with models. This is a hard and expensive task. Much effort has to be done in order to have corpus of texts and their corresponding summaries. Furthermore, for some methods, not only do we need to have human-made summaries available for comparison, but also manual annotation has to be performed in some of them (e.g. SCU in the Pyramid Method). In any case, what the evaluation methods need as an input, is a set of summaries to serve as gold standards and a set of automatic summaries. Moreover, they all perform a quantitative evaluation with regard to different similarity metrics.
"""

# %%
# !pip install -U Spacy
# Out:
# Collecting Spacy
#   Downloading https://files.pythonhosted.org/packages/10/b5/c7a92c7ce5d4b353b70b4b5b4385687206c8b230ddfe08746ab0fd310a3a/spacy-2.3.2-cp36-cp36m-manylinux1_x86_64.whl (9.9MB)
#      |████████████████████████████████| 10.0MB 2.6MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from Spacy) (1.18.5)
# Requirement already satisfied, skipping upgrade: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from Spacy) (2.23.0)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from Spacy) (2.0.3)
# Requirement already satisfied, skipping upgrade: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from Spacy) (0.4.1)
# Requirement already satisfied, skipping upgrade: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from Spacy) (1.0.2)
# Requirement already satisfied, skipping upgrade: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from Spacy) (0.7.1)
# Requirement already satisfied, skipping upgrade: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from Spacy) (3.0.2)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from Spacy) (4.41.1)
# Requirement already satisfied, skipping upgrade: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from Spacy) (1.1.3)
# Collecting thinc==7.4.1
#   Downloading https://files.pythonhosted.org/packages/10/ae/ef3ae5e93639c0ef8e3eb32e3c18341e511b3c515fcfc603f4b808087651/thinc-7.4.1-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 52.9MB/s
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from Spacy) (49.6.0)
# Requirement already satisfied, skipping upgrade: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from Spacy) (1.0.0)
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from Spacy) (1.0.2)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->Spacy) (2020.6.20)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->Spacy) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->Spacy) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->Spacy) (1.24.3)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->Spacy) (1.7.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->Spacy) (3.1.0)
# Installing collected packages: thinc, Spacy
#   Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# Successfully installed Spacy-2.3.2 thinc-7.4.1

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en_core_web_sm==2.3.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz (12.0MB)
#      |████████████████████████████████| 12.1MB 706kB/s
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from en_core_web_sm==2.3.1) (2.3.2)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.4.1)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (7.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (49.6.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.18.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.41.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.7.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.1.3)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.4)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.1.0)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py) ... done
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.3.1-cp36-none-any.whl size=12047109 sha256=5f98787c99dc081e2ab5224af7a2cb0cc2da8f3d477e67f4017fce65e77d3765
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hvrsveit/wheels/2b/3f/41/f0b92863355c3ba34bb32b37d8a0c662959da0058202094f46
# Successfully built en-core-web-sm
# Installing collected packages: en-core-web-sm
#   Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# Successfully installed en-core-web-sm-2.3.1
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
stopwords = list(STOP_WORDS)

# %%
# our NLP Model
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(text)

# %%
tokens = [token.text for token in doc]
print(tokens)
# Out:
# ['\n', 'Automatic', 'summarization', '\n', 'From', 'Wikipedia', ',', 'the', 'free', 'encyclopedia', '\n', 'Jump', 'to', 'navigationJump', 'to', 'search', '\n\n', 'This', 'article', 'has', 'multiple', 'issues', '.', 'Please', 'help', 'improve', 'it', 'or', 'discuss', 'these', 'issues', 'on', 'the', 'talk', 'page', '.', '(', 'Learn', 'how', 'and', 'when', 'to', 'remove', 'these', 'template', 'messages', ')', '\n', 'This', 'article', 'includes', 'a', 'list', 'of', 'references', ',', 'but', 'its', 'sources', 'remain', 'unclear', 'because', 'it', 'has', 'insufficient', 'inline', 'citations', '.', '(', 'March', '2015', ')', '\n', 'This', 'article', "'s", 'tone', 'or', 'style', 'may', 'not', 'reflect', 'the', 'encyclopedic', 'tone', 'used', 'on', 'Wikipedia', '.', '(', 'March', '2015', ')', '\n', 'Automatic', 'summarization', 'is', 'the', 'process', 'of', 'shortening', 'a', 'set', 'of', 'data', 'computationally', ',', 'to', 'create', 'a', 'subset', '(', 'a', 'summary', ')', 'that', 'represents', 'the', 'most', 'important', 'or', 'relevant', 'information', 'within', 'the', 'original', 'content', '.', '\n\n', 'In', 'addition', 'to', 'text', ',', 'images', 'and', 'videos', 'can', 'also', 'be', 'summarized', '.', 'Text', 'summarization', 'finds', 'the', 'most', 'informative', 'sentences', 'in', 'a', 'document[1', ']', ';', 'image', 'summarization', 'finds', 'the', 'most', 'representative', 'images', 'within', 'an', 'image', 'collection[citation', 'needed', ']', ';', 'video', 'summarization', 'extracts', 'the', 'most', 'important', 'frames', 'from', 'the', 'video', 'content.[2', ']', '\n\n', 'Approaches', '\n', 'There', 'are', 'two', 'general', 'approaches', 'to', 'automatic', 'summarization', ':', 'extraction', 'and', 'abstraction', '.', '\n\n', 'Extraction', '-', 'based', 'summarization', '\n', 'Here', ',', 'content', 'is', 'extracted', 'from', 'the', 'original', 'data', ',', 'but', 'the', 'extracted', 'content', 'is', 'not', 'modified', 'in', 'any', 'way', '.', 'Examples', 'of', 'extracted', 'content', 'include', 'key', '-', 'phrases', 'that', 'can', 'be', 'used', 'to', '"', 'tag', '"', 'or', 'index', 'a', 'text', 'document', ',', 'or', 'key', 'sentences', '(', 'including', 'headings', ')', 'that', 'collectively', 'comprise', 'an', 'abstract', ',', 'and', 'representative', 'images', 'or', 'video', 'segments', ',', 'as', 'stated', 'above', '.', 'For', 'text', ',', 'extraction', 'is', 'analogous', 'to', 'the', 'process', 'of', 'skimming', ',', 'where', 'the', 'summary', '(', 'if', 'available', ')', ',', 'headings', 'and', 'subheadings', ',', 'figures', ',', 'the', 'first', 'and', 'last', 'paragraphs', 'of', 'a', 'section', ',', 'and', 'optionally', 'the', 'first', 'and', 'last', 'sentences', 'in', 'a', 'paragraph', 'are', 'read', 'before', 'one', 'chooses', 'to', 'read', 'the', 'entire', 'document', 'in', 'detail.[3', ']', '\n\n', 'Abstraction', '-', 'based', 'summarization', '\n', 'This', 'has', 'been', 'applied', 'mainly', 'for', 'text', '.', 'Abstractive', 'methods', 'build', 'an', 'internal', 'semantic', 'representation', 'of', 'the', 'original', 'content', ',', 'and', 'then', 'use', 'this', 'representation', 'to', 'create', 'a', 'summary', 'that', 'is', 'closer', 'to', 'what', 'a', 'human', 'might', 'express', '.', 'Abstraction', 'may', 'transform', 'the', 'extracted', 'content', 'by', 'paraphrasing', 'sections', 'of', 'the', 'source', 'document', ',', 'to', 'condense', 'a', 'text', 'more', 'strongly', 'than', 'extraction', '.', 'Such', 'transformation', ',', 'however', ',', 'is', 'computationally', 'much', 'more', 'challenging', 'than', 'extraction', ',', 'involving', 'both', 'natural', 'language', 'processing', 'and', 'often', 'a', 'deep', 'understanding', 'of', 'the', 'domain', 'of', 'the', 'original', 'text', 'in', 'cases', 'where', 'the', 'original', 'document', 'relates', 'to', 'a', 'special', 'field', 'of', 'knowledge', '.', '"', 'Paraphrasing', '"', 'is', 'even', 'more', 'difficult', 'to', 'apply', 'to', 'image', 'and', 'vid ...

# %%
punctuation = punctuation + '\n'
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~\n'

# %%
word_frequencies = {}
for word in doc:
  if (word.text.lower() not in punctuation) and (word.text.lower() not in stopwords):
    if word.text not in word_frequencies.keys():
      word_frequencies[word.text] = 1
    else:
      word_frequencies[word.text] += 1

# %%
print(word_frequencies)
# Out:
# {'Automatic': 3, 'summarization': 82, 'Wikipedia': 2, 'free': 1, 'encyclopedia': 1, 'Jump': 1, 'navigationJump': 1, 'search': 4, '\n\n': 57, 'article': 7, 'multiple': 8, 'issues': 3, 'help': 2, 'improve': 2, 'discuss': 2, 'talk': 1, 'page': 1, 'Learn': 1, 'remove': 1, 'template': 1, 'messages': 1, 'includes': 1, 'list': 3, 'references': 3, 'sources': 3, 'remain': 1, 'unclear': 1, 'insufficient': 1, 'inline': 1, 'citations': 1, 'March': 2, '2015': 2, 'tone': 2, 'style': 1, 'reflect': 2, 'encyclopedic': 1, 'process': 7, 'shortening': 1, 'set': 20, 'data': 6, 'computationally': 2, 'create': 7, 'subset': 2, 'summary': 33, 'represents': 2, 'important': 12, 'relevant': 5, 'information': 16, 'original': 11, 'content': 10, 'addition': 2, 'text': 46, 'images': 7, 'videos': 4, 'summarized': 1, 'Text': 1, 'finds': 2, 'informative': 2, 'sentences': 33, 'document[1': 1, 'image': 7, 'representative': 4, 'collection[citation': 1, 'needed': 4, 'video': 5, 'extracts': 1, 'frames': 2, 'content.[2': 1, 'Approaches': 2, 'general': 5, 'approaches': 5, 'automatic': 12, 'extraction': 19, 'abstraction': 1, 'Extraction': 2, 'based': 24, 'extracted': 5, 'modified': 1, 'way': 13, 'Examples': 1, 'include': 7, 'key': 4, 'phrases': 6, 'tag': 1, 'index': 2, 'document': 40, 'including': 1, 'headings': 2, 'collectively': 1, 'comprise': 1, 'abstract': 3, 'segments': 2, 'stated': 1, 'analogous': 1, 'skimming': 1, 'available': 4, 'subheadings': 1, 'figures': 1, 'paragraphs': 1, 'section': 3, 'optionally': 1, 'paragraph': 1, 'read': 3, 'chooses': 1, 'entire': 2, 'detail.[3': 1, 'Abstraction': 3, 'applied': 6, 'mainly': 2, 'Abstractive': 1, 'methods': 14, 'build': 2, 'internal': 1, 'semantic': 3, 'representation': 3, 'use': 7, 'closer': 1, 'human': 12, 'express': 1, 'transform': 1, 'paraphrasing': 1, 'sections': 1, 'source': 5, 'condense': 1, 'strongly': 1, 'transformation': 1, 'challenging': 1, 'involving': 1, 'natural': 4, 'language': 4, 'processing': 6, 'deep': 2, 'understanding': 2, 'domain': 14, 'cases': 3, 'relates': 1, 'special': 5, 'field': 1, 'knowledge': 4, 'Paraphrasing': 1, 'difficult': 4, 'apply': 4, 'systems': 13, 'extractive': 5, 'Aided': 3, 'aimed': 2, 'higher': 1, 'quality': 1, 'rely': 2, 'combined': 4, 'software': 2, 'effort': 2, 'Machine': 2, 'Human': 3, 'Summarization': 4, 'techniques': 8, 'highlight': 1, 'candidate': 1, 'passages': 1, 'inclusion': 2, 'adds': 1, 'removes': 2, 'post': 3, 'processes': 2, 'output': 4, 'edits': 1, 'translation': 4, 'Google': 1, 'Translate': 1, 'Applications': 2, 'broadly': 1, 'types': 1, 'tasks': 4, 'depending': 2, 'program': 1, 'focuses': 2, 'generic': 4, 'obtaining': 1, 'collection': 5, 'documents': 15, 'sets': 2, 'news': 12, 'stories': 1, 'etc': 6, 'second': 2, 'query': 5, 'called': 6, 'summarizes': 4, 'objects': 3, 'specific': 7, 'able': 5, 'summaries': 24, 'machine': 6, 'generated': 5, 'user': 6, 'needs': 2, 'example': 21, 'problem': 10, 'attempts': 3, 'automatically': 6, 'produce': 11, 'given': 5, 'interested': 1, 'generating': 6, 'single': 4, 'cluster': 3, 'articles': 7, 'topic': 5, 'multi': 10, 'related': 4, 'application': 4, 'summarizing': 4, 'Imagine': 2, 'system': 17, 'pulls': 1, 'web': 1, 'concisely': 1, 'latest': 1, 'Image': 1, 'consists': 1, 'selecting': 3, 'larger': 4, 'images.[4': 1, 'context': 1, 'useful': 4, 'results': 10, 'exploration': 1, 'Video': 1, 'creates': 2, 'trailer': 1, 'long': 3, 'applications': 4, 'consumer': 1, 'personal': 1, 'want': 5, 'skip': 1, 'boring': 2, 'repetitive': 1, 'actions': 1, 'Similarly': 7, 'surveillance': 1, 'extract': 3, 'suspicious': 1, 'activity': 1, 'ignoring': 1, 'redundant': 2, 'captured': 1, 'high': 5, 'level': 3, 'algorithms': 8, 'try': 2, 'find': 3, 'subsets': 1, 'like': 11, 'cover': 7, 'core': 1, 'model': 10, 'notions': 2, 'diversity': 10, 'coverage': 6, 'representativeness': 1, 'Query': 1, 'additionally': 1, 'relevance': 4, 'naturally': 3, 'problems': 6, 'TextRank': 17, 'PageRank': 8, 'Submodular': 6, 'function': 9, 'Determinantal': 1, 'point': 3, 'maximal' ...

# %%
max_frequency = max(word_frequencies.values())
max_frequency
# Out:
# 82

# %%
# normaliziing word_frequencies
for word in word_frequencies.keys():
  word_frequencies[word] = word_frequencies[word]/max_frequency

# %%
print(word_frequencies)
# Out:
# {'Automatic': 0.036585365853658534, 'summarization': 1.0, 'Wikipedia': 0.024390243902439025, 'free': 0.012195121951219513, 'encyclopedia': 0.012195121951219513, 'Jump': 0.012195121951219513, 'navigationJump': 0.012195121951219513, 'search': 0.04878048780487805, '\n\n': 0.6951219512195121, 'article': 0.08536585365853659, 'multiple': 0.0975609756097561, 'issues': 0.036585365853658534, 'help': 0.024390243902439025, 'improve': 0.024390243902439025, 'discuss': 0.024390243902439025, 'talk': 0.012195121951219513, 'page': 0.012195121951219513, 'Learn': 0.012195121951219513, 'remove': 0.012195121951219513, 'template': 0.012195121951219513, 'messages': 0.012195121951219513, 'includes': 0.012195121951219513, 'list': 0.036585365853658534, 'references': 0.036585365853658534, 'sources': 0.036585365853658534, 'remain': 0.012195121951219513, 'unclear': 0.012195121951219513, 'insufficient': 0.012195121951219513, 'inline': 0.012195121951219513, 'citations': 0.012195121951219513, 'March': 0.024390243902439025, '2015': 0.024390243902439025, 'tone': 0.024390243902439025, 'style': 0.012195121951219513, 'reflect': 0.024390243902439025, 'encyclopedic': 0.012195121951219513, 'process': 0.08536585365853659, 'shortening': 0.012195121951219513, 'set': 0.24390243902439024, 'data': 0.07317073170731707, 'computationally': 0.024390243902439025, 'create': 0.08536585365853659, 'subset': 0.024390243902439025, 'summary': 0.4024390243902439, 'represents': 0.024390243902439025, 'important': 0.14634146341463414, 'relevant': 0.06097560975609756, 'information': 0.1951219512195122, 'original': 0.13414634146341464, 'content': 0.12195121951219512, 'addition': 0.024390243902439025, 'text': 0.5609756097560976, 'images': 0.08536585365853659, 'videos': 0.04878048780487805, 'summarized': 0.012195121951219513, 'Text': 0.012195121951219513, 'finds': 0.024390243902439025, 'informative': 0.024390243902439025, 'sentences': 0.4024390243902439, 'document[1': 0.012195121951219513, 'image': 0.08536585365853659, 'representative': 0.04878048780487805, 'collection[citation': 0.012195121951219513, 'needed': 0.04878048780487805, 'video': 0.06097560975609756, 'extracts': 0.012195121951219513, 'frames': 0.024390243902439025, 'content.[2': 0.012195121951219513, 'Approaches': 0.024390243902439025, 'general': 0.06097560975609756, 'approaches': 0.06097560975609756, 'automatic': 0.14634146341463414, 'extraction': 0.23170731707317074, 'abstraction': 0.012195121951219513, 'Extraction': 0.024390243902439025, 'based': 0.2926829268292683, 'extracted': 0.06097560975609756, 'modified': 0.012195121951219513, 'way': 0.15853658536585366, 'Examples': 0.012195121951219513, 'include': 0.08536585365853659, 'key': 0.04878048780487805, 'phrases': 0.07317073170731707, 'tag': 0.012195121951219513, 'index': 0.024390243902439025, 'document': 0.4878048780487805, 'including': 0.012195121951219513, 'headings': 0.024390243902439025, 'collectively': 0.012195121951219513, 'comprise': 0.012195121951219513, 'abstract': 0.036585365853658534, 'segments': 0.024390243902439025, 'stated': 0.012195121951219513, 'analogous': 0.012195121951219513, 'skimming': 0.012195121951219513, 'available': 0.04878048780487805, 'subheadings': 0.012195121951219513, 'figures': 0.012195121951219513, 'paragraphs': 0.012195121951219513, 'section': 0.036585365853658534, 'optionally': 0.012195121951219513, 'paragraph': 0.012195121951219513, 'read': 0.036585365853658534, 'chooses': 0.012195121951219513, 'entire': 0.024390243902439025, 'detail.[3': 0.012195121951219513, 'Abstraction': 0.036585365853658534, 'applied': 0.07317073170731707, 'mainly': 0.024390243902439025, 'Abstractive': 0.012195121951219513, 'methods': 0.17073170731707318, 'build': 0.024390243902439025, 'internal': 0.012195121951219513, 'semantic': 0.036585365853658534, 'representation': 0.036585365853658534, 'use': 0.08536585365853659, 'closer': 0.012195121951219513, 'human': 0.14634146341463414, 'express': 0.012195121951219513, 'transform': 0.012195121951219513, 'paraphrasing': 0.0121951 ...

# %%
# sentence tokenization
sentence_tokens = [sent for sent in doc.sents]
print(sentence_tokens)
# Out:
# [
# Automatic summarization
# From Wikipedia, the free encyclopedia
# Jump to navigationJump to search
#
# , This article has multiple issues., Please help improve it or discuss these issues on the talk page., (Learn how and when to remove these template messages)
# , This article includes a list of references, but its sources remain unclear because it has insufficient inline citations., (March 2015)
# , This article's tone or style may not reflect the encyclopedic tone used on Wikipedia., (March 2015)
# , Automatic summarization is the process of shortening a set of data computationally, to create a subset (a summary) that represents the most important or relevant information within the original content.
#
# , In addition to text, images and videos can also be summarized., Text summarization finds the most informative sentences in a document[1]; image summarization finds the most representative images within an image, collection[citation needed]; video summarization extracts the most important frames from the video content.[2]
#
# , Approaches
# , There are two general approaches to automatic summarization: extraction and abstraction.
#
# , Extraction-based summarization
# , Here, content is extracted from the original data, but the extracted content is not modified in any way., Examples of extracted content include key-phrases that can be used to "tag" or index a text document, or key sentences (including headings) that collectively comprise an abstract, and representative images or video segments, as stated above., For text, extraction is analogous to the process of skimming, where the summary (if available), headings and subheadings, figures, the first and last paragraphs of a section, and optionally the first and last sentences in a paragraph are read before one chooses to read the entire document in detail.[3]
#
# , Abstraction-based summarization
# , This has been applied mainly for text., Abstractive methods build an internal semantic representation of the original content, and then use this representation to create a summary that is closer to what a human might express., Abstraction may transform the extracted content by paraphrasing sections of the source document, to condense a text more strongly than extraction., Such transformation, however, is computationally much more challenging than extraction, involving both natural language processing and often a deep understanding of the domain of the original text in cases where the original document relates to a special field of knowledge., "Paraphrasing" is even more difficult to apply to image and video, which is why most summarization systems are extractive.
#
# , Aided summarization
# , Approaches aimed at higher summarization quality rely on combined software and human effort., In Machine Aided Human Summarization, extractive techniques highlight candidate passages for inclusion (to which the human adds or removes text)., In Human Aided Machine Summarization, a human post-processes software output, in the same way that one edits the output of automatic translation by Google Translate.
#
# , Applications and systems for summarization
# , There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on., The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.)., The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query., Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.
#
# , An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document., Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic)., This problem is called multi-document summarization., A related application is summarizing news articles., Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.
#
# , Image collection summarization is another application example of automatic summarization., It consists in selecting a representative set of images from a larger set of images.[4], A summary in this context is useful to show the most representative images of results in an image collection exploration system., Video summarization is a related domain, where the system automatically creates a trailer of a long video., This also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions., Similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured.
#
# , At a very high level, summarization algorithms try to find subsets of objects (like set of sentences, or a set of images), which cover information of the entire set., This is also called the core-set., These algorithms model notions like diversity, coverage, information and representativeness of the summary., Query based summarization techniques, additionally model for relevance of the summary with the query., Some techniques and algorithms which naturally model summarization problems are TextRank and PageRank, Submodular set function, Determinantal point process, maximal marginal relevance (MMR) etc.
#
# , Keyphrase extraction
# , The task is the following., You are given a piece of text, such as a journal article, and you must produce a list of keywords or key[phrase]s that capture the primary topics discussed in the text.[5], In the case of research articles, many authors provide manually assigned keywords, but most text lacks pre-existing keyphrases., For example, news articles rarely have keyphrases attached, but it would be useful to be able to automatically do so for a number of applications discussed below., Consider the example text from a news article:
#
# , "The Army Corps of Engineers, rushing to meet President Bush's promise to protect New Orleans by the start of the 2006 hurricane season, installed defective flood-control pumps last year despite warnings from its own expert that the equipment would fail during a storm, according to documents obtained by The Associated Press".
# , A keyphrase extractor might select "Army Corps of Engineers", "President Bush", "New Orleans", and "defective flood-control pumps" as keyphrases., These are pulled directly from the text., In contrast, an abstractive keyphrase system would somehow internalize the content and generate keyphrases that do not appear in the text, but more closely resemble what a human might produce, such as "political negligence" or "inadequate protection from floods"., Abstraction requires a deep understanding of the text, which makes it difficult for a computer system., Keyphrases have many applications., They can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.
#
# , Depending on the different literature and the definition of key terms, words or phrases, keyword extraction is a highly related theme.
#
# , Supervised learning approaches
# , Beginning with the work of Turney,[6], many researchers have approached keyphrase extraction as a supervised machine learning problem., Given a document, we construct an example for each unigram, bigram, and trigram found in the text (though other text units are also possible, as discussed below)., We then compute various features describing each example (e.g., does the phrase begin with an upper-case letter?)., We assume there are known keyphrases available for a set of training documents., Using the known keyphrases, we can assign positive or negative labels to the examples., Then we learn a classifier that can discriminate between positive and negative examples as a function of the features., Some classifiers make a binary classification for a test example, while others assign a probability of being a keyphrase., For instance, in the above text, we might learn a rule that says phrases with initial capital letters are likely to be keyphrases., After training a learner, we can select keyphrases for test documents in the following manner., We apply the same example-generation strategy to the test documents, then run each example through the learner., We can determine the keyphrases by looking at binary classification decisions or probabilities returned from our learned model., If probabilities are given, a threshold is used to select the keyphrases., Keyphrase extractors are generally evaluated using precision and recall., Precision measures how many of the proposed keyphrases are actually correct., Recall measures how many of the true keyphrases your system proposed., The two measures can be combined in an F-score, which is the harmonic mean of the two (F = 2PR/(P + R) )., Matches between the proposed keyphrases and the known keyphrases can be checked after stemming or applying some other text normalization.
#
# , Designing a supervised keyphrase extraction system involves deciding on several choices (some of these apply to unsupervised, too)., The first choice is exactly how to generate examples., Turney and others have used all possible unigrams, bigrams, and trigrams without intervening punctuation and after removing stopwords., Hulth showed that you can get some improvement by selecting examples to be sequences of tokens that match certain patterns of part-of-speech tags., Ideally, the mechanism for generating examples produces all the known labeled keyphrases as candidates, though this is often not the case., For example, if we use only unigrams, bigrams, and trigrams, then we will never be able to extract a known keyphrase containing four words., Thus, recall may suffer., However, generating too many examples can also lead to low precision.
#
# , We also need to create features that describe the examples and are informative enough to allow a learning algorithm to discriminate keyphrases from non- keyphrases., Typically features involve various term frequencies (how many times a phrase appears in the current text or in a larger corpus), the length of the example, relative position of the first occurrence, various boolean syntactic features (e.g., contains all caps), etc., The Turney paper used about 12 such features., Hulth uses a reduced set of features, which were found most successful in the KEA (Keyphrase Extraction Algorithm) work derived from Turney’s seminal paper.
#
# , In the end, the system will need to return a list of keyphrases for a test document, so we need to have a way to limit the number., Ensemble methods (i.e., using votes from several classifiers) have been used to produce numeric scores that can be thresholded to provide a user-provided number of keyphrases., This is the technique used by Turney with C4.5 decision trees., Hulth used a single binary classifier so the learning algorithm implicitly determines the appropriate number.
#
# , Once examples and features are created, we need a way to learn to predict keyphrases., Virtually any supervised learning algorithm could be used, such as decision trees, Naive Bayes, and rule induction., In the case of Turney's GenEx algorithm, a genetic algorithm is used to learn parameters for a domain-specific keyphrase extraction algorithm., The extractor follows a series of heuristics to identify keyphrases., The genetic algorithm optimizes parameters for these heuristics with respect to performance on training documents with known key phrases.
#
# , Unsupervised approach:, TextRank
# , Another keyphrase extraction algorithm is TextRank., While supervised methods have some nice properties, like being able to produce interpretable rules for what features characterize a keyphrase, they also require a large amount of training data., Many documents with known keyphrases are needed., Furthermore, training on a specific domain tends to customize the extraction process to that domain, so the resulting classifier is not necessarily portable, as some of Turney's results demonstrate., Unsupervised keyphrase extraction removes the need for training data., It approaches the problem from a different angle., Instead of trying to learn explicit features that characterize keyphrases, the TextRank algorithm[7] exploits the structure of the text itself to determine keyphrases that appear "central" to the text in the same way that PageRank selects important Web pages., Recall, this is based on the notion of "prestige" or "recommendation" from social networks., In this way, TextRank does not rely on any previous training data at all, but rather can be run on any arbitrary piece of text, and it can produce output simply based on the text's intrinsic properties., Thus the algorithm is easily portable to new domains and languages.
#
# , TextRank is a general purpose graph-based ranking algorithm for NLP., Essentially, it runs PageRank on a graph specially designed for a particular NLP task., For keyphrase extraction, it builds a graph using some set of text units as vertices., Edges are based on some measure of semantic or lexical similarity between the text unit vertices., Unlike PageRank, the edges are typically undirected and can be weighted to reflect a degree of similarity., Once the graph is constructed, it is used to form a stochastic matrix, combined with a damping factor (as in the "random surfer model"), and the ranking over vertices is obtained by finding the eigenvector corresponding to eigenvalue 1 (i.e., the stationary distribution of the random walk on the graph).
#
# , The vertices should correspond to what we want to rank., Potentially, we could do something similar to the supervised methods and create a vertex for each unigram, bigram, trigram, etc., However, to keep the graph small, the authors decide to rank individual unigrams in a first step, and then include a second step that merges highly ranked adjacent unigrams to form multi-word phrases., This has a nice side effect of allowing us to produce keyphrases of arbitrary length., For example, if we rank unigrams and find that "advanced", "natural", "language", and "processing" all get high ranks, then we would look at the original text and see that these words appear consecutively and create a final keyphrase using all four together., Note that the unigrams placed in the graph can be filtered by part of speech., The authors found that adjectives and nouns were the best to include., Thus, some linguistic knowledge comes into play in this step.
#
# , Edges are created based on word co-occurrence in this application of TextRank., Two vertices are connected by an edge if the unigrams appear within a window of size N in the original text., N is typically around 2–10., Thus, "natural" and "language" might be linked in a text about NLP., ", Natural" and "processing" would also be linked because they would both appear in the same string of N words., These edges build on the notion of "text cohesion" and the idea that words that appear near each other are likely related in a meaningful way and "recommend" each other to the reader.
#
# , Since this method simply ranks the individual vertices, we need a way to threshold or produce a limited number of keyphrases., The technique chosen is to set a count T to be a user-specified fraction of the total number of vertices in the graph., Then the top T vertices/unigrams are selected based on their stationary probabilities., A post- processing step is then applied to merge adjacent instances of these T unigrams., As a result, potentially more or less than T final keyphrases will be produced, but the number should be roughly proportional to the length of the original text.
#
# , It is not initially clear why applying PageRank to a co-occurrence graph would produce useful keyphrases., One way to think about it is the following., A word that appears multiple times throughout a text may have many different co-occurring neighbors., For example, in a text about machine learning, the unigram "learning" might co-occur with "machine", "supervised", "un-supervised", and "semi-supervised" in four different sentences., Thus, the "learning" vertex would be a central "hub" that connects to these other modifying words., Running PageRank/TextRank on the graph is likely to rank "learning" highly., Similarly, if the text contains the phrase "supervised classification", then there would be an edge between "supervised" and "classification"., If "classification" appears several other places and thus has many neighbors, its importance would contribute to the importance of "supervised"., If it ends up with a high rank, it will be selected as one of the top T unigrams, along with "learning" and probably "classification"., In the final post-processing step, we would then end up with keyphrases "supervised learning" and "supervised classification".
#
# , In short, the co-occurrence graph will contain densely connected regions for terms that appear often and in different contexts., A random walk on this graph will have a stationary distribution that assigns large probabilities to the terms in the centers of the clusters., This is similar to densely connected Web pages getting ranked highly by PageRank., This approach has also been used in document summarization, considered below.
#
# , Document summarization
# , Like keyphrase extraction, document summarization aims to identify the essence of a text., The only real difference is that now we are dealing with larger text units—whole sentences instead of words and phrases.
#
# , Before getting into the details of some summarization methods, we will mention how summarization systems are typically evaluated., The most common way is using the so-called ROUGE (Recall-Oriented Understudy for Gisting Evaluation) measure., This is a recall-based measure that determines how well a system-generated summary covers the content present in one or more human-generated model summaries known as references., It is recall-based to encourage systems to include all the important topics in the text., Recall can be computed with respect to unigram, bigram, trigram, or 4-gram matching., For example, ROUGE-1 is computed as division of count of unigrams in reference that appear in system and count of unigrams in reference summary.
#
# , If there are multiple references, the ROUGE-1 scores are averaged., Because ROUGE is based only on content overlap, it can determine if the same general concepts are discussed between an automatic summary and a reference summary, but it cannot determine if the result is coherent or the sentences flow together in a sensible manner., High-order n-gram ROUGE measures try to judge fluency to some degree., Note that ROUGE is similar to the BLEU measure for machine translation, but BLEU is precision-, based, because translation systems favor accuracy.
#
# , A promising line in document summarization is adaptive document/text summarization.[8], The idea of adaptive summarization involves preliminary recognition of document/text genre and subsequent application of summarization algorithms optimized for this genre., First summarizes that perform adaptive summarization have been created.[9]
#
# , Supervised learning approaches
# , Supervised text summarization is very much like supervised keyphrase extraction., Basically, if you have a collection of documents and human-generated summaries for them, you can learn features of sentences that make them good candidates for inclusion in the summary., Features might include the position in the document (i.e., the first few sentences are probably important), the number of words in the sentence, etc., The main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary"., This is not typically how people create summaries, so simply using journal abstracts or existing summaries is usually not sufficient., The sentences in these summaries do not necessarily match up with sentences in the original text, so it would be difficult to assign labels to examples for training., Note, however, that these natural summaries can still be used for evaluation purposes, since ROUGE-1 only cares about unigrams.
#
# , Maximum entropy-based summarization
# During the DUC 2001 and 2002 evaluation workshops, TNO developed a sentence extraction system for multi-document summarization in the news domain., The system was based on a hybrid system using a naive Bayes classifier and statistical language models for modeling salience., Although the system exhibited good results, the researchers wanted to explore the effectiveness of a maximum entropy (ME) classifier for the meeting summarization task, as ME is known to be robust against feature dependencies., Maximum entropy has also been applied successfully for summarization in the broadcast news domain.
#
# , TextRank and LexRank
# , The unsupervised approach to summarization is also quite similar in spirit to unsupervised keyphrase extraction and gets around the issue of costly training data., Some unsupervised summarization approaches are based on finding a "centroid" sentence, which is the mean word vector of all the sentences in the document., Then the sentences can be ranked with regard to their similarity to this centroid sentence.
#
# , A more principled way to estimate sentence importance is using random walks and eigenvector centrality., LexRank[10] is an algorithm essentially identical to TextRank, and both use this approach for document summarization., The two methods were developed by different groups at the same time, and LexRank simply focused on summarization, but could just as easily be used for keyphrase extraction or any other NLP ranking task.
#
# , In both LexRank and TextRank, a graph is constructed by creating a vertex for each sentence in the document.
#
# , The edges between sentences are based on some form of semantic similarity or content overlap., While LexRank uses cosine similarity of TF-IDF vectors, TextRank uses a very similar measure based on the number of words two sentences have in common (normalized by the sentences' lengths)., The LexRank paper explored using unweighted edges after applying a threshold to the cosine values, but also experimented with using edges with weights equal to the similarity score., TextRank uses continuous similarity scores as weights.
#
# , In both algorithms, the sentences are ranked by applying PageRank to the resulting graph., A summary is formed by combining the top ranking sentences, using a threshold or length cutoff to limit the size of the summary.
#
# , It is worth noting that TextRank was applied to summarization exactly as described here, while LexRank was used as part of a larger summarization system (MEAD) that combines the LexRank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights., In this case, some training documents might be needed, though the TextRank results show the additional features are not absolutely necessary.
#
# , Another important distinction is that TextRank was used for single document summarization, while LexRank has been applied to multi-document summarization., The task remains the same in both cases—only the number of sentences to choose from has grown., However, when summarizing multiple documents, there is a greater risk of selecting duplicate or highly redundant sentences to place in the same summary., Imagine you have a cluster of news articles on a particular event, and you want to produce one summary., Each article is likely to have many similar sentences, and you would only want to include distinct ideas in the summary., To address this issue, LexRank applies a heuristic post-processing step that builds up a summary by adding sentences in rank order, but discards any sentences that are too similar to ones already placed in the summary., The method used is called Cross-Sentence Information Subsumption (CSIS).
#
# , These methods work based on the idea that sentences "recommend" other similar sentences to the reader., Thus, if one sentence is very similar to many others, it will likely be a sentence of great importance., The importance of this sentence also stems from the importance of the sentences "recommending" it., Thus, to get ranked highly and placed in a summary, a sentence must be similar to many sentences that are in turn also similar to many other sentences., This makes intuitive sense and allows the algorithms to be applied to any arbitrary new text., The methods are domain-independent and easily portable., One could imagine the features indicating important sentences in the news domain might vary considerably from the biomedical domain., However, the unsupervised "recommendation"-based approach applies to any domain.
#
# , Multi-document summarization
# , Main article: Multi-document summarization
# , Multi-document summarization is an automatic procedure aimed at extraction of information from multiple texts written about the same topic., Resulting summary report allows individual users, such as professional information consumers, to quickly familiarize themselves with information contained in a large cluster of documents., In such a way, multi-document summarization systems are complementing the news aggregators performing the next step down the road of coping with information overload., Multi-document summarization may also be done in response to a question.[11]
#
# , Multi-document summarization creates information reports that are both concise and comprehensive., With different opinions being put together and outlined, every topic is described from multiple perspectives within a single document., While the goal of a brief summary is to simplify information search and cut the time by pointing to the most relevant source documents, comprehensive multi-document summary should itself contain the required information, hence limiting the need for accessing original files to cases when refinement is required., Automatic summaries present information extracted from multiple sources algorithmically, without any editorial touch or subjective human intervention, thus making it completely unbiased.[dubious – discuss]
#
# , Incorporating diversity
# Multi-document extractive summarization faces a problem of potential redundancy., Ideally, we would like to extract sentences that are both "central" (i.e., contain the main ideas) and "diverse" (i.e., they differ from one another)., LexRank deals with diversity as a heuristic final stage using CSIS, and other systems have used similar methods, such as Maximal Marginal Relevance (MMR),[12] in trying to eliminate redundancy in information retrieval results., There is a general purpose graph-based ranking algorithm like Page/Lex/TextRank that handles both "centrality" and "diversity" in a unified mathematical framework based on absorbing Markov chain random walks., (An absorbing random walk is like a standard random walk, except some states are now absorbing states that act as "black holes" that cause the walk to end abruptly at that state.), The algorithm is called GRASSHOPPER.[13], In addition to explicitly promoting diversity during the ranking process, GRASSHOPPER incorporates a prior ranking (based on sentence position in the case of summarization).
#
# , The state of the art results for multi-document summarization, however, are obtained using mixtures of submodular functions., These methods have achieved the state of the art results for Document Summarization Corpora, DUC 04 - 07.[14], Similar results were also achieved with the use of determinantal point processes (which are a special case of submodular functions) for DUC-04.[15]
#
# A new method for multi-lingual multi-document summarization that avoids redundancy works by simplifying and generating ideograms that represent the meaning of each sentence in each document and then evaluates similarity "qualitatively" by comparing the shape and position of said ideograms has recently been developed., This tool does not use word frequency, does not need training or preprocessing of any kind and works by generating ideograms that represent the meaning of each sentence and then summarizes using two user-supplied parameters: equivalence (when are two sentences to be considered equivalent) and relevance (how long is the desired summary).
#
# , Submodular functions as generic tools for summarization
# , The idea of a submodular set function has recently emerged as a powerful modeling tool for various summarization problems., Submodular functions naturally model notions of coverage, information, representation and diversity., Moreover, several important combinatorial optimization problems occur as special instances of submodular optimization., For example, the set cover problem is a special case of submodular optimization, since the set cover function is submodular., The set cover function attempts to find a subset of objects which cover a given set of concepts., For example, in document summarization, one would like the summary to cover all important and relevant concepts in the document., This is an instance of set cover., Similarly, the facility location problem is a special case of submodular functions., The Facility Location function also naturally models coverage and diversity., Another example of a submodular optimization problem is using a determinantal point process to model diversity., Similarly, the Maximum-Marginal-Relevance procedure can also be seen as an instance of submodular optimization., All these important models encouraging coverage, diversity and information are all submodular., Moreover, submodular functions can be efficiently combined together, and the resulting function is still submodular., Hence, one could combine one submodular function which models diversity, another one which models coverage and use human supervision to learn a right model of a submodular function for the problem.
#
# , While submodular functions are fitting problems for summarization, they also admit very efficient algorithms for optimization., For example, a simple greedy algorithm admits a constant factor guarantee.[16], Moreover, the greedy algorithm is extremely simple to implement and can scale to large datasets, which is very important for summarization problems.
#
# , Submodular functions have achieved state-of-the-art for almost all summarization problems., For example, work by Lin and Bilmes, 2012[17] shows that submodular functions achieve the best results to date on DUC-04, DUC-05, DUC-06 and DUC-07 systems for document summarization., Similarly, work by Lin and Bilmes, 2011,[18] shows that many existing systems for automatic summarization are instances of submodular functions., This was a breakthrough result establishing submodular functions as the right models for summarization problems.[citation needed]
#
# , Submodular Functions have also been used for other summarization tasks., Tschiatschek et al., 2014 show[19] that mixtures of submodular functions achieve state-of-the-art results for image collection summarization., Similarly, Bairi et al., 2015[20] show the utility of submodular functions for summarizing multi-document topic hierarchies., Submodular Functions have also successfully been used for summarizing machine learning datasets.[21]
#
# , Applications
# , [icon]
# This section needs expansion., You can help by adding to it., (February 2017)
# , Specific applications of automatic summarization include:
#
# , The Reddit bot "autotldr",[22] created in 2011 summarizes news articles in the comment-section of reddit posts., It was found to be very useful by the reddit community which upvoted its summaries hundreds of thousands of times.[23], The name is reference to TL;DR, −, Internet slang for "too long, ; didn't read".[24][25]
# , Evaluation techniques
# , The most common way to evaluate the informativeness of automatic summaries is to compare them with human-made model summaries.
#
# , Evaluation techniques fall into intrinsic and extrinsic,[26] inter-textual and intra-textual.[27]
#
# , Intrinsic and extrinsic evaluation
# , An intrinsic evaluation tests the summarization system in and of itself while an extrinsic evaluation tests the summarization based on how it affects the completion of some other task., Intrinsic evaluations have assessed mainly the coherence and informativeness of summaries., Extrinsic evaluations, on the other hand, have tested the impact of summarization on tasks like relevance assessment, reading comprehension, etc.
#
# , Inter-textual and intra-textual
# Intra-textual methods assess the output of a specific summarization system, and the inter-textual ones focus on contrastive analysis of outputs of several summarization systems.
#
# , Human judgement often has wide variance on what is considered a "good" summary, which means that making the evaluation process automatic is particularly difficult., Manual evaluation can be used, but this is both time and labor-intensive as it requires humans to read not only the summaries but also the source documents., Other issues are those concerning coherence and coverage.
#
# , One of the metrics used in NIST's annual Document Understanding Conferences, in which research groups submit their systems for both summarization and translation tasks, is the ROUGE metric (Recall-Oriented Understudy for Gisting Evaluation [2])., It essentially calculates n-gram overlaps between automatically generated summaries and previously-written human summaries., A high level of overlap should indicate a high level of shared concepts between the two summaries., Note that overlap metrics like this are unable to provide any feedback on a summary's coherence., Anaphor resolution remains another problem yet to be fully solved., Similarly, for image summarization, Tschiatschek et al., developed a Visual-ROUGE score which judges the performance of algorithms for image summarization.[28]
#
# , Domain specific versus domain independent summarization techniques
# , Domain independent summarization techniques generally apply sets of general features which can be used to identify information-rich text segments., Recent research focus has drifted to domain-specific summarization techniques that utilize the available knowledge specific to the domain of text., For example, automatic summarization research on medical text generally attempts to utilize the various sources of codified medical knowledge and ontologies.[29]
#
# , Evaluating summaries qualitatively
# , The main drawback of the evaluation systems existing so far is that we need at least one reference summary, and for some methods more than one, to be able to compare automatic summaries with models., This is a hard and expensive task., Much effort has to be done in order to have corpus of texts and their corresponding summaries., Furthermore, for some methods, not only do we need to have human-made summaries available for comparison, but also manual annotation has to be performed in some of them, (e.g. SCU in the Pyramid Method)., In any case, what the evaluation methods need as an input, is a set of summaries to serve as gold standards and a set of automatic summaries., Moreover, they all perform a quantitative evaluation with regard to different similarity metrics.
# ]

# %%
# getting sentence scores
sentence_scores = {}
for sent in sentence_tokens:
  for word in sent:
    if word.text in word_frequencies.keys(): 
      if sent not in sentence_scores.keys():
        sentence_scores[sent] = word_frequencies[word.text]
      else:
        sentence_scores[sent] += word_frequencies[word.text]

# %%
print(sentence_scores)
# Out:
# {
# Automatic summarization
# From Wikipedia, the free encyclopedia
# Jump to navigationJump to search
#
# : 1.853658536585366, This article has multiple issues.: 0.21951219512195122, Please help improve it or discuss these issues on the talk page.: 0.13414634146341464, (Learn how and when to remove these template messages)
# : 0.04878048780487805, This article includes a list of references, but its sources remain unclear because it has insufficient inline citations.: 0.26829268292682934, (March 2015)
# : 0.04878048780487805, This article's tone or style may not reflect the encyclopedic tone used on Wikipedia.: 0.20731707317073172, (March 2015)
# : 0.04878048780487805, Automatic summarization is the process of shortening a set of data computationally, to create a subset (a summary) that represents the most important or relevant information within the original content.
#
# : 3.3658536585365866, In addition to text, images and videos can also be summarized.: 0.7317073170731708, Text summarization finds the most informative sentences in a document[1]; image summarization finds the most representative images within an image: 2.804878048780488, collection[citation needed]; video summarization extracts the most important frames from the video content.[2]
#
# : 2.073170731707317, Approaches
# : 0.024390243902439025, There are two general approaches to automatic summarization: extraction and abstraction.
#
# : 2.2073170731707314, Extraction-based summarization
# : 1.3170731707317074, Here, content is extracted from the original data, but the extracted content is not modified in any way.: 0.7439024390243903, Examples of extracted content include key-phrases that can be used to "tag" or index a text document, or key sentences (including headings) that collectively comprise an abstract, and representative images or video segments, as stated above.: 2.2682926829268295, For text, extraction is analogous to the process of skimming, where the summary (if available), headings and subheadings, figures, the first and last paragraphs of a section, and optionally the first and last sentences in a paragraph are read before one chooses to read the entire document in detail.[3]
#
# : 3.1829268292682933, Abstraction-based summarization
# : 1.3292682926829267, This has been applied mainly for text.: 0.6585365853658537, Abstractive methods build an internal semantic representation of the original content, and then use this representation to create a summary that is closer to what a human might express.: 1.329268292682927, Abstraction may transform the extracted content by paraphrasing sections of the source document, to condense a text more strongly than extraction.: 1.6219512195121952, Such transformation, however, is computationally much more challenging than extraction, involving both natural language processing and often a deep understanding of the domain of the original text in cases where the original document relates to a special field of knowledge.: 2.1707317073170733, "Paraphrasing" is even more difficult to apply to image and video, which is why most summarization systems are extractive.
#
# : 2.1707317073170733, Aided summarization
# : 1.0365853658536586, Approaches aimed at higher summarization quality rely on combined software and human effort.: 1.3414634146341464, In Machine Aided Human Summarization, extractive techniques highlight candidate passages for inclusion (to which the human adds or removes text).: 1.1097560975609757, In Human Aided Machine Summarization, a human post-processes software output, in the same way that one edits the output of automatic translation by Google Translate.
#
# : 1.5609756097560976, Applications and systems for summarization
# : 1.1829268292682926, There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on.: 2.1951219512195124, The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.).: 2.207317073170732, The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query.: 2.804878048780488, Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.
#
# : 2.6219512195121952, An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document.: 3.6951219512195124, Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic).: 1.9512195121951224, This problem is called multi-document summarization.: 1.8048780487804879, A related application is summarizing news articles.: 0.37804878048780494, Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.
#
# : 1.975609756097561, Image collection summarization is another application example of automatic summarization.: 2.524390243902439, It consists in selecting a representative set of images from a larger set of images.[4]: 0.7317073170731707, A summary in this context is useful to show the most representative images of results in an image collection exploration system.: 1.0853658536585364, Video summarization is a related domain, where the system automatically creates a trailer of a long video.: 1.6463414634146343, This also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions.: 0.24390243902439027, Similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured.
#
# : 1.207317073170732, At a very high level, summarization algorithms try to find subsets of objects (like set of sentences, or a set of images), which cover information of the entire set.: 2.9634146341463428, This is also called the core-set.: 0.3292682926829268, These algorithms model notions like diversity, coverage, information and representativeness of the summary.: 1.1829268292682928, Query based summarization techniques, additionally model for relevance of the summary with the query.: 2.048780487804878, Some techniques and algorithms which naturally model summarization problems are TextRank and PageRank, Submodular set function, Determinantal point process, maximal marginal relevance (MMR) etc.
#
# : 3.1463414634146343, Keyphrase extraction
# : 0.2682926829268293, The task is the following.: 0.12195121951219512, You are given a piece of text, such as a journal article, and you must produce a list of keywords or key[phrase]s that capture the primary topics discussed in the text.[5]: 1.0731707317073171, In the case of research articles, many authors provide manually assigned keywords, but most text lacks pre-existing keyphrases.: 1.4024390243902438, For example, news articles rarely have keyphrases attached, but it would be useful to be able to automatically do so for a number of applications discussed below.: 1.280487804878049, Consider the example text from a news article:
#
# : 1.7560975609756098, "The Army Corps of Engineers, rushing to meet President Bush's promise to protect New Orleans by the start of the 2006 hurricane season, installed defective flood-control pumps last year despite warnings from its own expert that the equipment would fail during a storm, according to documents obtained by The Associated Press".
# : 0.7195121951219514, A keyphrase extractor might select "Army Corps of Engineers", "President Bush", "New Orleans", and "defective flood-control pumps" as keyphrases.: 0.902439024390244, These are pulled directly from the text.: 0.5853658536585367, In contrast, an abstractive keyphrase system would somehow internalize the content and generate keyphrases that do not appear in the text, but more closely resemble what a human might produce, such as "political negligence" or "inadequate protection from floods".: 1.9878048780487805, Abstraction requires a deep understanding of the text, which makes it difficult for a computer system.: 0.9634146341463415, Keyphrases have many applications.: 0.06097560975609756, They can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.
#
# : 4.3414634146341475, Depending on the different literature and the definition of key terms, words or phrases, keyword extraction is a highly related theme.
#
# : 1.475609756097561, Supervised learning approaches
# : 0.25609756097560976, Beginning with the work of Turney,[6]: 0.08536585365853658, many researchers have approached keyphrase extraction as a supervised machine learning problem.: 1.0121951219512195, Given a document, we construct an example for each unigram, bigram, and trigram found in the text (though other text units are also possible, as discussed below).: 2.1707317073170738, We then compute various features describing each example (e.g., does the phrase begin with an upper-case letter?).: 0.6951219512195123, We assume there are known keyphrases available for a set of training documents.: 1.1219512195121952, Using the known keyphrases, we can assign positive or negative labels to the examples.: 0.7073170731707318, Then we learn a classifier that can discriminate between positive and negative examples as a function of the features.: 0.6219512195121951, Some classifiers make a binary classification for a test example, while others assign a probability of being a keyphrase.: 0.7195121951219512, For instance, in the above text, we might learn a rule that says phrases with initial capital letters are likely to be keyphrases.: 1.25609756097561, After training a learner, we can select keyphrases for test documents in the following manner.: 0.8658536585365855, We apply the same example-generation strategy to the test documents, then run each example through the learner.: 0.8658536585365855, We can determine the keyphrases by looking at binary classification decisions or probabilities returned from our learned model.: 0.7560975609756098, If probabilities are given, a threshold is used to select the keyphrases.: 0.5609756097560976, Keyphrase extractors are generally evaluated using precision and recall.: 0.18292682926829268, Precision measures how many of the proposed keyphrases are actually correct.: 0.4878048780487805, Recall measures how many of the true keyphrases your system proposed.: 0.7317073170731707, The two measures can be combined in an F-score, which is the harmonic mean of the two (F = 2PR/(P + R) ).: 0.25609756097560976, Matches between the proposed keyphrases and the known keyphrases can be checked after stemming or applying some other text normalization.
#
# : 2.2439024390243905, Designing a supervised keyphrase extraction system involves deciding on several choices (some of these apply to unsupervised, too).: 1.0, The first choice is exactly how to generate examples.: 0.17073170731707318, Turney and others have used all possible unigrams, bigrams, and trigrams without intervening punctuation and after removing stopwords.: 0.35365853658536595, Hulth showed that you can get some improvement by selecting examples to be sequences of tokens that match certain patterns of part-of-speech tags.: 0.31707317073170743, Ideally, the mechanism for generating examples produces all the known labeled keyphrases as candidates, though this is often not the case.: 0.8902439024390244, For example, if we use only unigrams, bigrams, and trigrams, then we will never be able to extract a known keyphrase containing four words.: 1.0975609756097562, Thus, recall may suffer.: 0.06097560975609756, However, generating too many examples can also lead to low precision.
#
# : 0.9268292682926829, We also need to create features that describe the examples and are informative enough to allow a learning algorithm to discriminate keyphrases from non- keyphrases.: 1.6707317073170733, Typically features involve various term frequencies (how many times a phrase appears in the current text or in a larger corpus), the length of the example, relative position of the first occurrence, various boolean syntactic features (e.g., contains all caps), etc.: 1.7804878048780493, The Turney paper used about 12 such features.: 0.3048780487804878, Hulth uses a reduced set of features, which were found most successful in the KEA (Keyphrase Extraction Algorithm) work derived from Turney’s seminal paper.
#
# : 1.5609756097560976, In the end, the system will need to return a list of keyphrases for a test document, so we need to have a way to limit the number.: 1.768292682926829, Ensemble methods (i.e., using votes from several classifiers) have been used to produce numeric scores that can be thresholded to provide a user-provided number of keyphrases.: 1.0853658536585367, This is the technique used by Turney with C4.5 decision trees.: 0.15853658536585366, Hulth used a single binary classifier so the learning algorithm implicitly determines the appropriate number.
#
# : 1.3902439024390243, Once examples and features are created, we need a way to learn to predict keyphrases.: 1.0975609756097562, Virtually any supervised learning algorithm could be used, such as decision trees, Naive Bayes, and rule induction.: 0.6585365853658538, In the case of Turney's GenEx algorithm, a genetic algorithm is used to learn parameters for a domain-specific keyphrase extraction algorithm.: 1.5975609756097562, The extractor follows a series of heuristics to identify keyphrases.: 0.47560975609756095, The genetic algorithm optimizes parameters for these heuristics with respect to performance on training documents with known key phrases.
#
# : 1.5975609756097562, Unsupervised approach:: 0.08536585365853658, TextRank
# : 0.2073170731707317, Another keyphrase extraction algorithm is TextRank.: 0.8292682926829268, While supervised methods have some nice properties, like being able to produce interpretable rules for what features characterize a keyphrase, they also require a large amount of training data.: 1.4634146341463417, Many documents with known keyphrases are needed.: 0.7195121951219512, Furthermore, training on a specific domain tends to customize the extraction process to that domain, so the resulting classifier is not necessarily portable, as some of Turney's results demonstrate.: 1.304878048780488, Unsupervised keyphrase extraction removes the need for training data.: 0.8414634146341463, It approaches the problem from a different angle.: 0.29268292682926833, Instead of trying to learn explicit features that characterize keyphrases, the TextRank algorithm[7] exploits the structure of the text itself to determine keyphrases that appear "central" to the text in the same way that PageRank selects important Web pages.: 3.085365853658537, Recall: 0.06097560975609756, this is based on the notion of "prestige" or "recommendation" from social networks.: 0.3658536585365854, In this way, TextRank does not rely on any previous training data at all, but rather can be run on any arbitrary piece of text, and it can produce output simply based on the text's intrinsic properties.: 2.4146341463414642, Thus the algorithm is easily portable to new domains and languages.
#
# : 1.0121951219512195, TextRank is a general purpose graph-based ranking algorithm for NLP.: 1.0853658536585367, Essentially, it runs PageRank on a graph specially designed for a particular NLP task.: 0.48780487804878053, For keyphrase extraction, it builds a graph using some set of text units as vertices.: 1.5853658536585367, Edges are based on some measure of semantic or lexical similarity between the text unit vertices.: 1.207317073170732, Unlike PageRank, the edges are typically undirected and can be weighted to reflect a degree of similarity.: 0.4024390243902439, Once the graph is constructed, it is used to form a stochastic matrix, combined with a damping factor (as in the "random surfer model"), and the ranking over vertices is obtained by finding the eigenvector corresponding to eigenvalue 1 (i.e., the stationary distribution of the random walk on the graph).
#
# : 2.048780487804878, The vertices should correspond to what we want to rank.: 0.24390243902439024, Potentially, we could do something similar to the supervised methods and create a vertex for each unigram, bigram, trigram, etc.: 0.8292682926829269, However, to keep the graph small, the authors decide to rank individual unigrams in a first step, and then include a second step that merges highly ranked adjacent unigrams to form multi-word phrases.: 1.4146341463414633, This has a nice side effect of allowing us to produce keyphrases of arbitrary length.: 0.6463414634146343, For example, if we rank unigrams and find that "advanced", "natural", "language", and "processing" all get high ranks, then we would look at the original text and see that these words appear consecutively and create a final keyphrase using all four together.: 2.060975609756098, Note that the unigrams placed in the graph can be filtered by part of speech.: 0.46341463414634154, The authors found that adjectives and nouns were the best to include.: 0.2195121951219512, Thus, some linguistic knowledge comes into play in this step.
#
# : 0.8658536585365852, Edges are created based on word co-occurrence in this application of TextRank.: 0.7926829268292683, Two vertices are connected by an edge if the unigrams appear within a window of size N in the original text.: 1.1829268292682928, N is typically around 2–10.: 0.09756097560975609, Thus, "natural" and "language" might be linked in a text about NLP.: 0.7317073170731708, Natural" and "processing" would also be linked because they would both appear in the same string of N words.: 0.36585365853658536, These edges build on the notion of "text cohesion" and the idea that words that appear near each other are likely related in a meaningful way and "recommend" each other to the reader.
#
# : 1.975609756097561, Since this method simply ranks the individual vertices, we need a way to threshold or produce a limited number of keyphrases.: 1.2195121951219514, The technique chosen is to set a count T to be a user-specified fraction of the total number of vertices in the graph.: 0.9024390243902438, Then the top T vertices/unigrams are selected based on their stationary probabilities.: 0.7317073170731708, A post- processing step is then applied to merge adjacent instances of these T unigrams.: 0.5365853658536586, As a result, potentially more or less than T final keyphrases will be produced, but the number should be roughly proportional to the length of the original text.
#
# : 2.1341463414634143, It is not initially clear why applying PageRank to a co-occurrence graph would produce useful keyphrases.: 1.0121951219512195, One way to think about it is the following.: 0.20731707317073172, A word that appears multiple times throughout a text may have many different co-occurring neighbors.: 0.975609756097561, For example, in a text about machine learning, the unigram "learning" might co-occur with "machine", "supervised", "un-supervised", and "semi-supervised" in four different sentences.: 2.4878048780487805, Thus, the "learning" vertex would be a central "hub" that connects to these other modifying words.: 0.3780487804878049, Running PageRank/TextRank on the graph is likely to rank "learning" highly.: 0.8658536585365854, Similarly, if the text contains the phrase "supervised classification", then there would be an edge between "supervised" and "classification".: 1.2682926829268293, If "classification" appears several other places and thus has many neighbors, its importance would contribute to the importance of "supervised".: 0.5, If it ends up with a high rank, it will be selected as one of the top T unigrams, along with "learning" and probably "classification".: 0.6585365853658537, In the final post-processing step, we would then end up with keyphrases "supervised learning" and "supervised classification".
#
# : 1.951219512195122, In short, the co-occurrence graph will contain densely connected regions for terms that appear often and in different contexts.: 0.6707317073170731, A random walk on this graph will have a stationary distribution that assigns large probabilities to the terms in the centers of the clusters.: 0.5853658536585367, This is similar to densely connected Web pages getting ranked highly by PageRank.: 0.5121951219512195, This approach has also been used in document summarization, considered below.
#
# : 2.2804878048780486, Document summarization
# : 1.0365853658536586, Like keyphrase extraction, document summarization aims to identify the essence of a text.: 2.5609756097560976, The only real difference is that now we are dealing with larger text units—whole sentences instead of words and phrases.
#
# : 2.0, Before getting into the details of some summarization methods, we will mention how summarization systems are typically evaluated.: 2.4512195121951224, The most common way is using the so-called ROUGE (Recall-Oriented Understudy for Gisting Evaluation) measure.: 0.5853658536585367, This is a recall-based measure that determines how well a system-generated summary covers the content present in one or more human-generated model summaries known as references.: 2.0365853658536586, It is recall-based to encourage systems to include all the important topics in the text.: 1.329268292682927, Recall can be computed with respect to unigram, bigram, trigram, or 4-gram matching.: 0.25609756097560976, For example, ROUGE-1 is computed as division of count of unigrams in reference that appear in system and count of unigrams in reference summary.
#
# : 2.2439024390243905, If there are multiple references, the ROUGE-1 scores are averaged.: 0.21951219512195125, Because ROUGE is based only on content overlap, it can determine if the same general concepts are discussed between an automatic summary and a reference summary, but it cannot determine if the result is coherent or the sentences flow together in a sensible manner.: 2.304878048780488, High-order n-gram ROUGE measures try to judge fluency to some degree.: 0.2926829268292683, Note that ROUGE is similar to the BLEU measure for machine translation, but BLEU is precision-: 0.5121951219512195, based, because translation systems favor accuracy.
#
# : 1.2195121951219512, A promising line in document summarization is adaptive document/text summarization.[8]: 2.6097560975609757, The idea of adaptive summarization involves preliminary recognition of document/text genre and subsequent application of summarization algorithms optimized for this genre.: 3.4024390243902443, First summarizes that perform adaptive summarization have been created.[9]
#
# : 1.8170731707317074, Supervised learning approaches
# : 0.25609756097560976, Supervised text summarization is very much like supervised keyphrase extraction.: 2.353658536585366, Basically, if you have a collection of documents and human-generated summaries for them, you can learn features of sentences that make them good candidates for inclusion in the summary.: 1.9146341463414633, Features might include the position in the document (i.e., the first few sentences are probably important), the number of words in the sentence, etc.: 1.7560975609756098, The main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary".: 4.195121951219512, This is not typically how people create summaries, so simply using journal abstracts or existing summaries is usually not sufficient.: 0.8902439024390245, The sentences in these summaries do not necessarily match up with sentences in the original text, so it would be difficult to assign labels to examples for training.: 2.2073170731707323, Note, however, that these natural summaries can still be used for evaluation purposes, since ROUGE-1 only cares about unigrams.
#
# : 1.4268292682926829, Maximum entropy-based summarization
# During the DUC 2001 and 2002 evaluation workshops, TNO developed a sentence extraction system for multi-document summarization in the news domain.: 4.146341463414634, The system was based on a hybrid system using a naive Bayes classifier and statistical language models for modeling salience.: 1.0, Although the system exhibited good results, the researchers wanted to explore the effectiveness of a maximum entropy (ME) classifier for the meeting summarization task, as ME is known to be robust against feature dependencies.: 1.804878048780488, Maximum entropy has also been applied successfully for summarization in the broadcast news domain.
#
# : 2.195121951219512, TextRank and LexRank
# : 0.3292682926829268, The unsupervised approach to summarization is also quite similar in spirit to unsupervised keyphrase extraction and gets around the issue of costly training data.: 2.048780487804878, Some unsupervised summarization approaches are based on finding a "centroid" sentence, which is the mean word vector of all the sentences in the document.: 2.6219512195121952, Then the sentences can be ranked with regard to their similarity to this centroid sentence.
#
# : 1.4878048780487805, A more principled way to estimate sentence importance is using random walks and eigenvector centrality.: 0.5853658536585367, LexRank[10] is an algorithm essentially identical to TextRank, and both use this approach for document summarization.: 2.073170731707317, The two methods were developed by different groups at the same time, and LexRank simply focused on summarization, but could just as easily be used for keyphrase extraction or any other NLP ranking task.
#
# : 2.951219512195122, In both LexRank and TextRank, a graph is constructed by creating a vertex for each sentence in the document.
#
# : 1.9390243902439026, The edges between sentences are based on some form of semantic similarity or content overlap.: 1.1097560975609757, While LexRank uses cosine similarity of TF-IDF vectors, TextRank uses a very similar measure based on the number of words two sentences have in common (normalized by the sentences' lengths).: 2.1951219512195124, The LexRank paper explored using unweighted edges after applying a threshold to the cosine values, but also experimented with using edges with weights equal to the similarity score.: 0.6585365853658537, TextRank uses continuous similarity scores as weights.
#
# : 1.146341463414634, In both algorithms, the sentences are ranked by applying PageRank to the resulting graph.: 0.9268292682926831, A summary is formed by combining the top ranking sentences, using a threshold or length cutoff to limit the size of the summary.
#
# : 2.1829268292682924, It is worth noting that TextRank was applied to summarization exactly as described here, while LexRank was used as part of a larger summarization system (MEAD) that combines the LexRank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights.: 3.853658536585367, In this case, some training documents might be needed, though the TextRank results show the additional features are not absolutely necessary.
#
# : 1.7439024390243902, Another important distinction is that TextRank was used for single document summarization, while LexRank has been applied to multi-document summarization.: 3.707317073170732, The task remains the same in both cases—only the number of sentences to choose from has grown.: 0.7195121951219513, However, when summarizing multiple documents, there is a greater risk of selecting duplicate or highly redundant sentences to place in the same summary.: 1.3170731707317074, Imagine you have a cluster of news articles on a particular event, and you want to produce one summary.: 0.926829268292683, Each article is likely to have many similar sentences, and you would only want to include distinct ideas in the summary.: 1.2804878048780488, To address this issue, LexRank applies a heuristic post-processing step that builds up a summary by adding sentences in rank order, but discards any sentences that are too similar to ones already placed in the summary.: 2.3902439024390247, The method used is called Cross-Sentence Information Subsumption (CSIS).
#
# : 0.8780487804878048, These methods work based on the idea that sentences "recommend" other similar sentences to the reader.: 1.5731707317073171, Thus, if one sentence is very similar to many others, it will likely be a sentence of great importance.: 0.6341463414634146, The importance of this sentence also stems from the importance of the sentences "recommending" it.: 0.7439024390243902, Thus, to get ranked highly and placed in a summary, a sentence must be similar to many sentences that are in turn also similar to many other sentences.: 1.8536585365853662, This makes intuitive sense and allows the algorithms to be applied to any arbitrary new text.: 0.8780487804878049, The methods are domain-independent and easily portable.: 0.4512195121951219, One could imagine the features indicating important sentences in the news domain might vary considerably from the biomedical domain.: 1.2804878048780488, However, the unsupervised "recommendation"-based approach applies to any domain.
#
# : 1.024390243902439, Multi-document summarization
# : 1.5609756097560976, Main article: Multi-document summarization
# : 1.6585365853658536, Multi-document summarization is an automatic procedure aimed at extraction of information from multiple texts written about the same topic.: 2.3902439024390247, Resulting summary report allows individual users, such as professional information consumers, to quickly familiarize themselves with information contained in a large cluster of documents.: 1.2317073170731707, In such a way, multi-document summarization systems are complementing the news aggregators performing the next step down the road of coping with information overload.: 2.4268292682926833, Multi-document summarization may also be done in response to a question.[11]
#
# : 2.2804878048780486, Multi-document summarization creates information reports that are both concise and comprehensive.: 1.829268292682927, With different opinions being put together and outlined, every topic is described from multiple perspectives within a single document.: 0.8536585365853658, While the goal of a brief summary is to simplify information search and cut the time by pointing to the most relevant source documents, comprehensive multi-document summary should itself contain the required information, hence limiting the need for accessing original files to cases when refinement is required.: 2.719512195121952, Automatic summaries present information extracted from multiple sources algorithmically, without any editorial touch or subjective human intervention, thus making it completely unbiased.[dubious – discuss]
#
# : 1.731707317073171, Incorporating diversity
# Multi-document extractive summarization faces a problem of potential redundancy.: 1.9390243902439024, Ideally, we would like to extract sentences that are both "central" (i.e., contain the main ideas) and "diverse" (i.e., they differ from one another).: 0.8780487804878052, LexRank deals with diversity as a heuristic final stage using CSIS, and other systems have used similar methods, such as Maximal Marginal Relevance (MMR),[12] in trying to eliminate redundancy in information retrieval results.: 1.3292682926829271, There is a general purpose graph-based ranking algorithm like Page/Lex/TextRank that handles both "centrality" and "diversity" in a unified mathematical framework based on absorbing Markov chain random walks.: 1.8536585365853664, (An absorbing random walk is like a standard random walk, except some states are now absorbing states that act as "black holes" that cause the walk to end abruptly at that state.): 0.780487804878049, The algorithm is called GRASSHOPPER.[13]: 0.2682926829268293, In addition to explicitly promoting diversity during the ranking process, GRASSHOPPER incorporates a prior ranking (based on sentence position in the case of summarization).
#
# : 2.8048780487804876, The state of the art results for multi-document summarization, however, are obtained using mixtures of submodular functions.: 2.304878048780488, These methods have achieved the state of the art results for Document Summarization Corpora, DUC 04 - 07.[14]: 0.5853658536585367, Similar results were also achieved with the use of determinantal point processes (which are a special case of submodular functions) for DUC-04.[15]
#
# A new method for multi-lingual multi-document summarization that avoids redundancy works by simplifying and generating ideograms that represent the meaning of each sentence in each document and then evaluates similarity "qualitatively" by comparing the shape and position of said ideograms has recently been developed.: 4.70731707317073, This tool does not use word frequency, does not need training or preprocessing of any kind and works by generating ideograms that represent the meaning of each sentence and then summarizes using two user-supplied parameters: equivalence (when are two sentences to be considered equivalent) and relevance (how long is the desired summary).
#
# : 2.6707317073170733, Submodular functions as generic tools for summarization
# : 1.2926829268292683, The idea of a submodular set function has recently emerged as a powerful modeling tool for various summarization problems.: 1.8170731707317076, Submodular functions naturally model notions of coverage, information, representation and diversity.: 0.8414634146341463, Moreover, several important combinatorial optimization problems occur as special instances of submodular optimization.: 0.7439024390243901, For example, the set cover problem is a special case of submodular optimization, since the set cover function is submodular.: 1.8902439024390247, The set cover function attempts to find a subset of objects which cover a given set of concepts.: 1.0121951219512195, For example, in document summarization, one would like the summary to cover all important and relevant concepts in the document.: 3.1097560975609757, This is an instance of set cover.: 0.36585365853658536, Similarly, the facility location problem is a special case of submodular functions.: 0.8170731707317073, The Facility Location function also naturally models coverage and diversity.: 0.45121951219512196, Another example of a submodular optimization problem is using a determinantal point process to model diversity.: 1.0853658536585367, Similarly, the Maximum-Marginal-Relevance procedure can also be seen as an instance of submodular optimization.: 0.5609756097560975, All these important models encouraging coverage, diversity and information are all submodular.: 0.8780487804878049, Moreover, submodular functions can be efficiently combined together, and the resulting function is still submodular.: 0.8536585365853658, Hence, one could combine one submodular function which models diversity, another one which models coverage and use human supervision to learn a right model of a submodular function for the problem.
#
# : 2.3780487804878048, While submodular functions are fitting problems for summarization, they also admit very efficient algorithms for optimization.: 1.6829268292682928, For example, a simple greedy algorithm admits a constant factor guarantee.[16]: 0.5487804878048781, Moreover, the greedy algorithm is extremely simple to implement and can scale to large datasets, which is very important for summarization problems.
#
# : 2.2560975609756095, Submodular functions have achieved state-of-the-art for almost all summarization problems.: 1.451219512195122, For example, work by Lin and Bilmes, 2012[17] shows that submodular functions achieve the best results to date on DUC-04, DUC-05, DUC-06 and DUC-07 systems for document summarization.: 2.682926829268293, Similarly, work by Lin and Bilmes, 2011,[18] shows that many existing systems for automatic summarization are instances of submodular functions.: 2.024390243902439, This was a breakthrough result establishing submodular functions as the right models for summarization problems.[citation needed]
#
# : 2.3292682926829267, Submodular Functions have also been used for other summarization tasks.: 1.1463414634146343, Tschiatschek et al., 2014 show[19] that mixtures of submodular functions achieve state-of-the-art results for image collection summarization.: 1.9512195121951221, Similarly, Bairi et al., 2015[20] show the utility of submodular functions for summarizing multi-document topic hierarchies.: 1.3292682926829271, Submodular Functions have also successfully been used for summarizing machine learning datasets.[21]
#
# : 1.1097560975609757, Applications
# : 0.024390243902439025, [icon]
# This section needs expansion.: 0.09756097560975609, You can help by adding to it.: 0.04878048780487805, (February 2017)
# : 0.024390243902439025, Specific applications of automatic summarization include:
#
# : 1.9878048780487805, The Reddit bot "autotldr",[22] created in 2011 summarizes news articles in the comment-section of reddit posts.: 0.46341463414634154, It was found to be very useful by the reddit community which upvoted its summaries hundreds of thousands of times.[23]: 0.475609756097561, The name is reference to TL;DR: 0.07317073170731707, −: 0.012195121951219513, Internet slang for "too long: 0.06097560975609756, ; didn't read".[24][25]
# : 0.012195121951219513, Evaluation techniques
# : 0.14634146341463417, The most common way to evaluate the informativeness of automatic summaries is to compare them with human-made model summaries.
#
# : 1.951219512195122, Evaluation techniques fall into intrinsic and extrinsic,[26] inter-textual and intra-textual.[27]
#
# : 1.024390243902439, Intrinsic and extrinsic evaluation
# : 0.17073170731707316, An intrinsic evaluation tests the summarization system in and of itself while an extrinsic evaluation tests the summarization based on how it affects the completion of some other task.: 2.9634146341463414, Intrinsic evaluations have assessed mainly the coherence and informativeness of summaries.: 0.4390243902439024, Extrinsic evaluations, on the other hand, have tested the impact of summarization on tasks like relevance assessment, reading comprehension, etc.
#
# : 2.109756097560976, Inter-textual and intra-textual
# Intra-textual methods assess the output of a specific summarization system, and the inter-textual ones focus on contrastive analysis of outputs of several summarization systems.
#
# : 3.7804878048780486, Human judgement often has wide variance on what is considered a "good" summary, which means that making the evaluation process automatic is particularly difficult.: 1.0, Manual evaluation can be used, but this is both time and labor-intensive as it requires humans to read not only the summaries but also the source documents.: 0.8048780487804879, Other issues are those concerning coherence and coverage.
#
# : 0.8536585365853657, One of the metrics used in NIST's annual Document Understanding Conferences, in which research groups submit their systems for both summarization and translation tasks, is the ROUGE metric (Recall-Oriented Understudy for Gisting Evaluation [2]).: 1.7439024390243905, It essentially calculates n-gram overlaps between automatically generated summaries and previously-written human summaries.: 1.0, A high level of overlap should indicate a high level of shared concepts between the two summaries.: 0.6097560975609756, Note that overlap metrics like this are unable to provide any feedback on a summary's coherence.: 0.7682926829268293, Anaphor resolution remains another problem yet to be fully solved.: 0.1951219512195122, Similarly, for image summarization, Tschiatschek et al., developed a Visual-ROUGE score which judges the performance of algorithms for image summarization.[28]
#
# : 2.378048780487805, Domain specific versus domain independent summarization techniques
# : 1.426829268292683, Domain independent summarization techniques generally apply sets of general features which can be used to identify information-rich text segments.: 2.3414634146341466, Recent research focus has drifted to domain-specific summarization techniques that utilize the available knowledge specific to the domain of text.: 2.3902439024390247, For example, automatic summarization research on medical text generally attempts to utilize the various sources of codified medical knowledge and ontologies.[29]
#
# : 2.963414634146342, Evaluating summaries qualitatively
# : 0.32926829268292684, The main drawback of the evaluation systems existing so far is that we need at least one reference summary, and for some methods more than one, to be able to compare automatic summaries with models.: 1.7682926829268295, This is a hard and expensive task.: 0.10975609756097562, Much effort has to be done in order to have corpus of texts and their corresponding summaries.: 0.4390243902439024, Furthermore, for some methods, not only do we need to have human-made summaries available for comparison, but also manual annotation has to be performed in some of them: 0.8658536585365855, (e.g. SCU in the Pyramid Method).: 0.07317073170731707, In any case, what the evaluation methods need as an input, is a set of summaries to serve as gold standards and a set of automatic summaries.: 1.8170731707317074, Moreover, they all perform a quantitative evaluation with regard to different similarity metrics.
# : 0.4268292682926829}

# %% [markdown]
# Getting the 30% of sentences with the maximum score to be our extractive summary.

# %%
from heapq import nlargest

# %%
select_length = int(len(sentence_tokens) * 0.3)
select_length
# Out:
# 90

# %%
summary = nlargest(select_length, sentence_scores, key=sentence_scores.get)

# %%
summary
# Out:
# [Similar results were also achieved with the use of determinantal point processes (which are a special case of submodular functions) for DUC-04.[15]
#
#  A new method for multi-lingual multi-document summarization that avoids redundancy works by simplifying and generating ideograms that represent the meaning of each sentence in each document and then evaluates similarity "qualitatively" by comparing the shape and position of said ideograms has recently been developed.,
#  They can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.
#  ,
#  The main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary".,
#  Maximum entropy-based summarization
#  During the DUC 2001 and 2002 evaluation workshops, TNO developed a sentence extraction system for multi-document summarization in the news domain.,
#  It is worth noting that TextRank was applied to summarization exactly as described here, while LexRank was used as part of a larger summarization system (MEAD) that combines the LexRank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights.,
#  Inter-textual and intra-textual
#  Intra-textual methods assess the output of a specific summarization system, and the inter-textual ones focus on contrastive analysis of outputs of several summarization systems.
#  ,
#  Another important distinction is that TextRank was used for single document summarization, while LexRank has been applied to multi-document summarization.,
#  An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document.,
#  The idea of adaptive summarization involves preliminary recognition of document/text genre and subsequent application of summarization algorithms optimized for this genre.,
#  Automatic summarization is the process of shortening a set of data computationally, to create a subset (a summary) that represents the most important or relevant information within the original content.
#  ,
#  For text, extraction is analogous to the process of skimming, where the summary (if available), headings and subheadings, figures, the first and last paragraphs of a section, and optionally the first and last sentences in a paragraph are read before one chooses to read the entire document in detail.[3]
#  ,
#  Some techniques and algorithms which naturally model summarization problems are TextRank and PageRank, Submodular set function, Determinantal point process, maximal marginal relevance (MMR) etc.
#  ,
#  For example, in document summarization, one would like the summary to cover all important and relevant concepts in the document.,
#  Instead of trying to learn explicit features that characterize keyphrases, the TextRank algorithm[7] exploits the structure of the text itself to determine keyphrases that appear "central" to the text in the same way that PageRank selects important Web pages.,
#  At a very high level, summarization algorithms try to find subsets of objects (like set of sentences, or a set of images), which cover information of the entire set.,
#  For example, automatic summarization research on medical text generally attempts to utilize the various sources of codified medical knowledge and ontologies.[29]
#  ,
#  An intrinsic evaluation tests the summarization system in and of itself while an extrinsic evaluation tests the summarization based on how it affects the completion of some other task.,
#  The two methods were developed by different groups at the same time, and LexRank simply focused on summarization, but could just as easily be used for keyphrase extraction or any other NLP ranking task.
#  ,
#  Text summarization finds the most informative sentences in a document[1]; image summarization finds the most representative images within an image,
#  The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query.,
#  In addition to explicitly promoting diversity during the ranking process, GRASSHOPPER incorporates a prior ranking (based on sentence position in the case of summarization).
#  ,
#  While the goal of a brief summary is to simplify information search and cut the time by pointing to the most relevant source documents, comprehensive multi-document summary should itself contain the required information, hence limiting the need for accessing original files to cases when refinement is required.,
#  For example, work by Lin and Bilmes, 2012[17] shows that submodular functions achieve the best results to date on DUC-04, DUC-05, DUC-06 and DUC-07 systems for document summarization.,
#  This tool does not use word frequency, does not need training or preprocessing of any kind and works by generating ideograms that represent the meaning of each sentence and then summarizes using two user-supplied parameters: equivalence (when are two sentences to be considered equivalent) and relevance (how long is the desired summary).
#  ,
#  Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.
#  ,
#  Some unsupervised summarization approaches are based on finding a "centroid" sentence, which is the mean word vector of all the sentences in the document.,
#  A promising line in document summarization is adaptive document/text summarization.[8],
#  Like keyphrase extraction, document summarization aims to identify the essence of a text.,
#  Image collection summarization is another application example of automatic summarization.,
#  For example, in a text about machine learning, the unigram "learning" might co-occur with "machine", "supervised", "un-supervised", and "semi-supervised" in four different sentences.,
#  Before getting into the details of some summarization methods, we will mention how summarization systems are typically evaluated.,
#  In such a way, multi-document summarization systems are complementing the news aggregators performing the next step down the road of coping with information overload.,
#  In this way, TextRank does not rely on any previous training data at all, but rather can be run on any arbitrary piece of text, and it can produce output simply based on the text's intrinsic properties.,
#  To address this issue, LexRank applies a heuristic post-processing step that builds up a summary by adding sentences in rank order, but discards any sentences that are too similar to ones already placed in the summary.,
#  Multi-document summarization is an automatic procedure aimed at extraction of information from multiple texts written about the same topic.,
#  Recent research focus has drifted to domain-specific summarization techniques that utilize the available knowledge specific to the domain of text.,
#  Similarly, for image summarization, Tschiatschek et al., developed a Visual-ROUGE score which judges the performance of algorithms for image summarization.[28]
#  ,
#  Hence, one could combine one submodular function which models diversity, another one which models coverage and use human supervision to learn a right model of a submodular function for the problem.
#  ,
#  Supervised text summarization is very much like supervised keyphrase extraction.,
#  Domain independent summarization techniques generally apply sets of general features which can be used to identify information-rich text segments.,
#  This was a breakthrough result establishing submodular functions as the right models for summarization problems.[citation needed]
#  ,
#  Because ROUGE is based only on content overlap, it can determine if the same general concepts are discussed between an automatic summary and a reference summary, but it cannot determine if the result is coherent or the sentences flow together in a sensible manner.,
#  The state of the art results for multi-document summarization, however, are obtained using mixtures of submodular functions.,
#  This approach has also been used in document summarization, considered below.
#  ,
#  Multi-document summarization may also be done in response to a question.[11]
#  ,
#  Examples of extracted content include key-phrases that can be used to "tag" or index a text document, or key sentences (including headings) that collectively comprise an abstract, and representative images or video segments, as stated above.,
#  Moreover, the greedy algorithm is extremely simple to implement and can scale to large datasets, which is very important for summarization problems.
#  ,
#  Matches between the proposed keyphrases and the known keyphrases can be checked after stemming or applying some other text normalization.
#  ,
#  For example, ROUGE-1 is computed as division of count of unigrams in reference that appear in system and count of unigrams in reference summary.
#  ,
#  The sentences in these summaries do not necessarily match up with sentences in the original text, so it would be difficult to assign labels to examples for training.,
#  The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.).,
#  There are two general approaches to automatic summarization: extraction and abstraction.
#  ,
#  There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on.,
#  While LexRank uses cosine similarity of TF-IDF vectors, TextRank uses a very similar measure based on the number of words two sentences have in common (normalized by the sentences' lengths).,
#  Maximum entropy has also been applied successfully for summarization in the broadcast news domain.
#  ,
#  A summary is formed by combining the top ranking sentences, using a threshold or length cutoff to limit the size of the summary.
#  ,
#  Given a document, we construct an example for each unigram, bigram, and trigram found in the text (though other text units are also possible, as discussed below).,
#  Such transformation, however, is computationally much more challenging than extraction, involving both natural language processing and often a deep understanding of the domain of the original text in cases where the original document relates to a special field of knowledge.,
#  "Paraphrasing" is even more difficult to apply to image and video, which is why most summarization systems are extractive.
#  ,
#  As a result, potentially more or less than T final keyphrases will be produced, but the number should be roughly proportional to the length of the original text.
#  ,
#  Extrinsic evaluations, on the other hand, have tested the impact of summarization on tasks like relevance assessment, reading comprehension, etc.
#  ,
#  collection[citation needed]; video summarization extracts the most important frames from the video content.[2]
#  ,
#  LexRank[10] is an algorithm essentially identical to TextRank, and both use this approach for document summarization.,
#  For example, if we rank unigrams and find that "advanced", "natural", "language", and "processing" all get high ranks, then we would look at the original text and see that these words appear consecutively and create a final keyphrase using all four together.,
#  Query based summarization techniques, additionally model for relevance of the summary with the query.,
#  Once the graph is constructed, it is used to form a stochastic matrix, combined with a damping factor (as in the "random surfer model"), and the ranking over vertices is obtained by finding the eigenvector corresponding to eigenvalue 1 (i.e., the stationary distribution of the random walk on the graph).
#  ,
#  The unsupervised approach to summarization is also quite similar in spirit to unsupervised keyphrase extraction and gets around the issue of costly training data.,
#  This is a recall-based measure that determines how well a system-generated summary covers the content present in one or more human-generated model summaries known as references.,
#  Similarly, work by Lin and Bilmes, 2011,[18] shows that many existing systems for automatic summarization are instances of submodular functions.,
#  The only real difference is that now we are dealing with larger text units—whole sentences instead of words and phrases.
#  ,
#  In contrast, an abstractive keyphrase system would somehow internalize the content and generate keyphrases that do not appear in the text, but more closely resemble what a human might produce, such as "political negligence" or "inadequate protection from floods".,
#  Specific applications of automatic summarization include:
#  ,
#  Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.
#  ,
#  These edges build on the notion of "text cohesion" and the idea that words that appear near each other are likely related in a meaningful way and "recommend" each other to the reader.
#  ,
#  Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic).,
#  Tschiatschek et al., 2014 show[19] that mixtures of submodular functions achieve state-of-the-art results for image collection summarization.,
#  In the final post-processing step, we would then end up with keyphrases "supervised learning" and "supervised classification".
#  ,
#  The most common way to evaluate the informativeness of automatic summaries is to compare them with human-made model summaries.
#  ,
#  In both LexRank and TextRank, a graph is constructed by creating a vertex for each sentence in the document.
#  ,
#  Incorporating diversity
#  Multi-document extractive summarization faces a problem of potential redundancy.,
#  Basically, if you have a collection of documents and human-generated summaries for them, you can learn features of sentences that make them good candidates for inclusion in the summary.,
#  For example, the set cover problem is a special case of submodular optimization, since the set cover function is submodular.,
#  There is a general purpose graph-based ranking algorithm like Page/Lex/TextRank that handles both "centrality" and "diversity" in a unified mathematical framework based on absorbing Markov chain random walks.,
#  Thus, to get ranked highly and placed in a summary, a sentence must be similar to many sentences that are in turn also similar to many other sentences.,
#
#  Automatic summarization
#  From Wikipedia, the free encyclopedia
#  Jump to navigationJump to search
#  ,
#  Multi-document summarization creates information reports that are both concise and comprehensive.,
#  The idea of a submodular set function has recently emerged as a powerful modeling tool for various summarization problems.,
#  First summarizes that perform adaptive summarization have been created.[9]
#  ,
#  In any case, what the evaluation methods need as an input, is a set of summaries to serve as gold standards and a set of automatic summaries.,
#  Although the system exhibited good results, the researchers wanted to explore the effectiveness of a maximum entropy (ME) classifier for the meeting summarization task, as ME is known to be robust against feature dependencies.]

# %% [markdown]
# We now need to combine these sentences together.

# %%
final_summary = [word.text for word in summary]
final_summary
# Out:
# ['Similar results were also achieved with the use of determinantal point processes (which are a special case of submodular functions) for DUC-04.[15]\n\nA new method for multi-lingual multi-document summarization that avoids redundancy works by simplifying and generating ideograms that represent the meaning of each sentence in each document and then evaluates similarity "qualitatively" by comparing the shape and position of said ideograms has recently been developed.',
#  'They can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.\n\n',
#  'The main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary".',
#  'Maximum entropy-based summarization\nDuring the DUC 2001 and 2002 evaluation workshops, TNO developed a sentence extraction system for multi-document summarization in the news domain.',
#  'It is worth noting that TextRank was applied to summarization exactly as described here, while LexRank was used as part of a larger summarization system (MEAD) that combines the LexRank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights.',
#  'Inter-textual and intra-textual\nIntra-textual methods assess the output of a specific summarization system, and the inter-textual ones focus on contrastive analysis of outputs of several summarization systems.\n\n',
#  'Another important distinction is that TextRank was used for single document summarization, while LexRank has been applied to multi-document summarization.',
#  'An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document.',
#  'The idea of adaptive summarization involves preliminary recognition of document/text genre and subsequent application of summarization algorithms optimized for this genre.',
#  'Automatic summarization is the process of shortening a set of data computationally, to create a subset (a summary) that represents the most important or relevant information within the original content.\n\n',
#  'For text, extraction is analogous to the process of skimming, where the summary (if available), headings and subheadings, figures, the first and last paragraphs of a section, and optionally the first and last sentences in a paragraph are read before one chooses to read the entire document in detail.[3]\n\n',
#  'Some techniques and algorithms which naturally model summarization problems are TextRank and PageRank, Submodular set function, Determinantal point process, maximal marginal relevance (MMR) etc.\n\n',
#  'For example, in document summarization, one would like the summary to cover all important and relevant concepts in the document.',
#  'Instead of trying to learn explicit features that characterize keyphrases, the TextRank algorithm[7] exploits the structure of the text itself to determine keyphrases that appear "central" to the text in the same way that PageRank selects important Web pages.',
#  'At a very high level, summarization algorithms try to find subsets of objects (like set of sentences, or a set of images), which cover information of the entire set.',
#  'For example, automatic summarization research on medical text generally attempts to utilize the various sources of codified medical knowledge and ontologies.[29]\n\n',
#  'An intrinsic evaluation tests the summarization system in and of itself while an extrinsic evaluation tests the summarization based on how it affects the completion of some other task.',
#  'The two methods were developed by different groups at the same time, and LexRank simply focused on summarization, but could just as easily be used for keyphrase extraction or any other NLP ranking task.\n\n',
#  'Text summarization finds the most informative sentences in a document[1]; image summarization finds the most representative images within an image',
#  'The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query.',
#  'In addition to explicitly promoting diversity during the ranking process, GRASSHOPPER incorporates a prior ranking (based on sentence position in the case of summarization).\n\n',
#  'While the goal of a brief summary is to simplify information search and cut the time by pointing to the most relevant source documents, comprehensive multi-document summary should itself contain the required information, hence limiting the need for accessing original files to cases when refinement is required.',
#  'For example, work by Lin and Bilmes, 2012[17] shows that submodular functions achieve the best results to date on DUC-04, DUC-05, DUC-06 and DUC-07 systems for document summarization.',
#  'This tool does not use word frequency, does not need training or preprocessing of any kind and works by generating ideograms that represent the meaning of each sentence and then summarizes using two user-supplied parameters: equivalence (when are two sentences to be considered equivalent) and relevance (how long is the desired summary).\n\n',
#  'Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.\n\n',
#  'Some unsupervised summarization approaches are based on finding a "centroid" sentence, which is the mean word vector of all the sentences in the document.',
#  'A promising line in document summarization is adaptive document/text summarization.[8]',
#  'Like keyphrase extraction, document summarization aims to identify the essence of a text.',
#  'Image collection summarization is another application example of automatic summarization.',
#  'For example, in a text about machine learning, the unigram "learning" might co-occur with "machine", "supervised", "un-supervised", and "semi-supervised" in four different sentences.',
#  'Before getting into the details of some summarization methods, we will mention how summarization systems are typically evaluated.',
#  'In such a way, multi-document summarization systems are complementing the news aggregators performing the next step down the road of coping with information overload.',
#  "In this way, TextRank does not rely on any previous training data at all, but rather can be run on any arbitrary piece of text, and it can produce output simply based on the text's intrinsic properties.",
#  'To address this issue, LexRank applies a heuristic post-processing step that builds up a summary by adding sentences in rank order, but discards any sentences that are too similar to ones already placed in the summary.',
#  'Multi-document summarization is an automatic procedure aimed at extraction of information from multiple texts written about the same topic.',
#  'Recent research focus has drifted to domain-specific summarization techniques that utilize the available knowledge specific to the domain of text.',
#  'Similarly, for image summarization, Tschiatschek et al., developed a Visual-ROUGE score which judges the performance of algorithms for image summarization.[28]\n\n',
#  'Hence, one could combine one submodular function which models diversity, another one which models coverage and use human supervision to learn a right model of a submodular function for the problem.\n\n',
#  'Supervised text summarization is very much like supervised keyphrase extraction.',
#  'Domain independent summarization techniques generally apply sets of general features which can be used to identify information-rich text segments.',
#  'This was a breakthrough result establishing submodular functions as the right models for summarization problems.[citation needed]\n\n',
#  'Because ROUGE is based only on content overlap, it can determine if the same general concepts are discussed between an automatic summary and a reference summary, but it cannot determine if the result is coherent or the sentences flow together in a sensible manner.',
#  'The state of the art results for multi-document summarization, however, are obtained using mixtures of submodular functions.',
#  'This approach has also been used in document summarization, considered below.\n\n',
#  'Multi-document summarization may also be done in response to a question.[11]\n\n',
#  'Examples of extracted content include key-phrases that can be used to "tag" or index a text document, or key sentences (including headings) that collectively comprise an abstract, and representative images or video segments, as stated above.',
#  'Moreover, the greedy algorithm is extremely simple to implement and can scale to large datasets, which is very important for summarization problems.\n\n',
#  'Matches between the proposed keyphrases and the known keyphrases can be checked after stemming or applying some other text normalization.\n\n',
#  'For example, ROUGE-1 is computed as division of count of unigrams in reference that appear in system and count of unigrams in reference summary.\n\n',
#  'The sentences in these summaries do not necessarily match up with sentences in the original text, so it would be difficult to assign labels to examples for training.',
#  'The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.).',
#  'There are two general approaches to automatic summarization: extraction and abstraction.\n\n',
#  'There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on.',
#  "While LexRank uses cosine similarity of TF-IDF vectors, TextRank uses a very similar measure based on the number of words two sentences have in common (normalized by the sentences' lengths).",
#  'Maximum entropy has also been applied successfully for summarization in the broadcast news domain.\n\n',
#  'A summary is formed by combining the top ranking sentences, using a threshold or length cutoff to limit the size of the summary.\n\n',
#  'Given a document, we construct an example for each unigram, bigram, and trigram found in the text (though other text units are also possible, as discussed below).',
#  'Such transformation, however, is computationally much more challenging than extraction, involving both natural language processing and often a deep understanding of the domain of the original text in cases where the original document relates to a special field of knowledge.',
#  '"Paraphrasing" is even more difficult to apply to image and video, which is why most summarization systems are extractive.\n\n',
#  'As a result, potentially more or less than T final keyphrases will be produced, but the number should be roughly proportional to the length of the original text.\n\n',
#  'Extrinsic evaluations, on the other hand, have tested the impact of summarization on tasks like relevance assessment, reading comprehension, etc.\n\n',
#  'collection[citation needed]; video summarization extracts the most important frames from the video content.[2]\n\n',
#  'LexRank[10] is an algorithm essentially identical to TextRank, and both use this approach for document summarization.',
#  'For example, if we rank unigrams and find that "advanced", "natural", "language", and "processing" all get high ranks, then we would look at the original text and see that these words appear consecutively and create a final keyphrase using all four together.',
#  'Query based summarization techniques, additionally model for relevance of the summary with the query.',
#  'Once the graph is constructed, it is used to form a stochastic matrix, combined with a damping factor (as in the "random surfer model"), and the ranking over vertices is obtained by finding the eigenvector corresponding to eigenvalue 1 (i.e., the stationary distribution of the random walk on the graph).\n\n',
#  'The unsupervised approach to summarization is also quite similar in spirit to unsupervised keyphrase extraction and gets around the issue of costly training data.',
#  'This is a recall-based measure that determines how well a system-generated summary covers the content present in one or more human-generated model summaries known as references.',
#  'Similarly, work by Lin and Bilmes, 2011,[18] shows that many existing systems for automatic summarization are instances of submodular functions.',
#  'The only real difference is that now we are dealing with larger text units—whole sentences instead of words and phrases.\n\n',
#  'In contrast, an abstractive keyphrase system would somehow internalize the content and generate keyphrases that do not appear in the text, but more closely resemble what a human might produce, such as "political negligence" or "inadequate protection from floods".',
#  'Specific applications of automatic summarization include:\n\n',
#  'Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.\n\n',
#  'These edges build on the notion of "text cohesion" and the idea that words that appear near each other are likely related in a meaningful way and "recommend" each other to the reader.\n\n',
#  'Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic).',
#  'Tschiatschek et al., 2014 show[19] that mixtures of submodular functions achieve state-of-the-art results for image collection summarization.',
#  'In the final post-processing step, we would then end up with keyphrases "supervised learning" and "supervised classification".\n\n',
#  'The most common way to evaluate the informativeness of automatic summaries is to compare them with human-made model summaries.\n\n',
#  'In both LexRank and TextRank, a graph is constructed by creating a vertex for each sentence in the document.\n\n',
#  'Incorporating diversity\nMulti-document extractive summarization faces a problem of potential redundancy.',
#  'Basically, if you have a collection of documents and human-generated summaries for them, you can learn features of sentences that make them good candidates for inclusion in the summary.',
#  'For example, the set cover problem is a special case of submodular optimization, since the set cover function is submodular.',
#  'There is a general purpose graph-based ranking algorithm like Page/Lex/TextRank that handles both "centrality" and "diversity" in a unified mathematical framework based on absorbing Markov chain random walks.',
#  'Thus, to get ranked highly and placed in a summary, a sentence must be similar to many sentences that are in turn also similar to many other sentences.',
#  '\nAutomatic summarization\nFrom Wikipedia, the free encyclopedia\nJump to navigationJump to search\n\n',
#  'Multi-document summarization creates information reports that are both concise and comprehensive.',
#  'The idea of a submodular set function has recently emerged as a powerful modeling tool for various summarization problems.',
#  'First summarizes that perform adaptive summarization have been created.[9]\n\n',
#  'In any case, what the evaluation methods need as an input, is a set of summaries to serve as gold standards and a set of automatic summaries.',
#  'Although the system exhibited good results, the researchers wanted to explore the effectiveness of a maximum entropy (ME) classifier for the meeting summarization task, as ME is known to be robust against feature dependencies.']

# %%
summary = ' '.join(final_summary)

# %%
print(text)
# Out:
# Automatic summarization
# From Wikipedia, the free encyclopedia
# Jump to navigationJump to search
#
# This article has multiple issues. Please help improve it or discuss these issues on the talk page. (Learn how and when to remove these template messages)
# This article includes a list of references, but its sources remain unclear because it has insufficient inline citations. (March 2015)
# This article's tone or style may not reflect the encyclopedic tone used on Wikipedia. (March 2015)
# Automatic summarization is the process of shortening a set of data computationally, to create a subset (a summary) that represents the most important or relevant information within the original content.
#
# In addition to text, images and videos can also be summarized. Text summarization finds the most informative sentences in a document[1]; image summarization finds the most representative images within an image collection[citation needed]; video summarization extracts the most important frames from the video content.[2]
#
# Approaches
# There are two general approaches to automatic summarization: extraction and abstraction.
#
# Extraction-based summarization
# Here, content is extracted from the original data, but the extracted content is not modified in any way. Examples of extracted content include key-phrases that can be used to "tag" or index a text document, or key sentences (including headings) that collectively comprise an abstract, and representative images or video segments, as stated above. For text, extraction is analogous to the process of skimming, where the summary (if available), headings and subheadings, figures, the first and last paragraphs of a section, and optionally the first and last sentences in a paragraph are read before one chooses to read the entire document in detail.[3]
#
# Abstraction-based summarization
# This has been applied mainly for text. Abstractive methods build an internal semantic representation of the original content, and then use this representation to create a summary that is closer to what a human might express. Abstraction may transform the extracted content by paraphrasing sections of the source document, to condense a text more strongly than extraction. Such transformation, however, is computationally much more challenging than extraction, involving both natural language processing and often a deep understanding of the domain of the original text in cases where the original document relates to a special field of knowledge. "Paraphrasing" is even more difficult to apply to image and video, which is why most summarization systems are extractive.
#
# Aided summarization
# Approaches aimed at higher summarization quality rely on combined software and human effort. In Machine Aided Human Summarization, extractive techniques highlight candidate passages for inclusion (to which the human adds or removes text). In Human Aided Machine Summarization, a human post-processes software output, in the same way that one edits the output of automatic translation by Google Translate.
#
# Applications and systems for summarization
# There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on. The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.). The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query. Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.
#
# An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document. Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic). This problem is called multi-document summarization. A related application is summarizing news articles. Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.
#
# Image collection summarization is another application example of automatic summarization. It consists in selecting a representative set of images from a larger set of images.[4] A summary in this context is useful to show the most representative images of results in an image collection exploration system. Video summarization is a related domain, where the system automatically creates a trailer of a long video. This also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions. Similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured.
#
# At a very high level, summarization algorithms try to find subsets of objects (like set of sentences, or a set of images), which cover information of the entire set. This is also called the core-set. These algorithms model notions like diversity, coverage, information and representativeness of the summary. Query based summarization techniques, additionally model for relevance of the summary with the query. Some techniques and algorithms which naturally model summarization problems are TextRank and PageRank, Submodular set function, Determinantal point process, maximal marginal relevance (MMR) etc.
#
# Keyphrase extraction
# The task is the following. You are given a piece of text, such as a journal article, and you must produce a list of keywords or key[phrase]s that capture the primary topics discussed in the text.[5] In the case of research articles, many authors provide manually assigned keywords, but most text lacks pre-existing keyphrases. For example, news articles rarely have keyphrases attached, but it would be useful to be able to automatically do so for a number of applications discussed below. Consider the example text from a news article:
#
# "The Army Corps of Engineers, rushing to meet President Bush's promise to protect New Orleans by the start of the 2006 hurricane season, installed defective flood-control pumps last year despite warnings from its own expert that the equipment would fail during a storm, according to documents obtained by The Associated Press".
# A keyphrase extractor might select "Army Corps of Engineers", "President Bush", "New Orleans", and "defective flood-control pumps" as keyphrases. These are pulled directly from the text. In contrast, an abstractive keyphrase system would somehow internalize the content and generate keyphrases that do not appear in the text, but more closely resemble what a human might produce, such as "political negligence" or "inadequate protection from floods". Abstraction requires a deep understanding of the text, which makes it difficult for a computer system. Keyphrases have many applications. They can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.
#
# Depending on the different literature and the definition of key terms, words or phrases, keyword extraction is a highly related theme.
#
# Supervised learning approaches
# Beginning with the work of Turney,[6] many researchers have approached keyphrase extraction as a supervised machine learning problem. Given a document, we construct an example for each unigram, bigram, and trigram found in the text (though other text units are also possible, as discussed below). We then compute various features describing each example (e.g., does the phrase begin with an upper-case letter?). We assume there are known keyphrases available for a set of training documents. Using the known keyphrases, we can assign positive or negative labels to the examples. Then we learn a classifier that can discriminate between positive and negative examples as a function of the features. Some classifiers make a binary classification for a test example, while others assign a probability of being a keyphrase. For instance, in the above text, we might learn a rule that says phrases with initial capital letters are likely to be keyphrases. After training a learner, we can select keyphrases for test documents in the following manner. We apply the same example-generation strategy to the test documents, then run each example through the learner. We can determine the keyphrases by looking at binary classification decisions or probabilities returned from our learned model. If probabilities are given, a threshold is used to select the keyphrases. Keyphrase extractors are generally evaluated using precision and recall. Precision measures how many of the proposed keyphrases are actually correct. Recall measures how many of the true keyphrases your system proposed. The two measures can be combined in an F-score, which is the harmonic mean of the two (F = 2PR/(P + R) ). Matches between the proposed keyphrases and the known keyphrases can be checked after stemming or applying some other text normalization.
#
# Designing a supervised keyphrase extraction system involves deciding on several choices (some of these apply to unsupervised, too). The first choice is exactly how to generate examples. Turney and others have used all possible unigrams, bigrams, and trigrams without intervening punctuation and after removing stopwords. Hulth showed that you can get some improvement by selecting examples to be sequences of tokens that match certain patterns of part-of-speech tags. Ideally, the mechanism for generating examples produces all the known labeled keyphrases as candidates, though this is often not the case. For example, if we use only unigrams, bigrams, and trigrams, then we will never be able to extract a known keyphrase containing four words. Thus, recall may suffer. However, generating too many examples can also lead to low precision.
#
# We also need to create features that describe the examples and are informative enough to allow a learning algorithm to discriminate keyphrases from non- keyphrases. Typically features involve various term frequencies (how many times a phrase appears in the current text or in a larger corpus), the length of the example, relative position of the first occurrence, various boolean syntactic features (e.g., contains all caps), etc. The Turney paper used about 12 such features. Hulth uses a reduced set of features, which were found most successful in the KEA (Keyphrase Extraction Algorithm) work derived from Turney’s seminal paper.
#
# In the end, the system will need to return a list of keyphrases for a test document, so we need to have a way to limit the number. Ensemble methods (i.e., using votes from several classifiers) have been used to produce numeric scores that can be thresholded to provide a user-provided number of keyphrases. This is the technique used by Turney with C4.5 decision trees. Hulth used a single binary classifier so the learning algorithm implicitly determines the appropriate number.
#
# Once examples and features are created, we need a way to learn to predict keyphrases. Virtually any supervised learning algorithm could be used, such as decision trees, Naive Bayes, and rule induction. In the case of Turney's GenEx algorithm, a genetic algorithm is used to learn parameters for a domain-specific keyphrase extraction algorithm. The extractor follows a series of heuristics to identify keyphrases. The genetic algorithm optimizes parameters for these heuristics with respect to performance on training documents with known key phrases.
#
# Unsupervised approach: TextRank
# Another keyphrase extraction algorithm is TextRank. While supervised methods have some nice properties, like being able to produce interpretable rules for what features characterize a keyphrase, they also require a large amount of training data. Many documents with known keyphrases are needed. Furthermore, training on a specific domain tends to customize the extraction process to that domain, so the resulting classifier is not necessarily portable, as some of Turney's results demonstrate. Unsupervised keyphrase extraction removes the need for training data. It approaches the problem from a different angle. Instead of trying to learn explicit features that characterize keyphrases, the TextRank algorithm[7] exploits the structure of the text itself to determine keyphrases that appear "central" to the text in the same way that PageRank selects important Web pages. Recall this is based on the notion of "prestige" or "recommendation" from social networks. In this way, TextRank does not rely on any previous training data at all, but rather can be run on any arbitrary piece of text, and it can produce output simply based on the text's intrinsic properties. Thus the algorithm is easily portable to new domains and languages.
#
# TextRank is a general purpose graph-based ranking algorithm for NLP. Essentially, it runs PageRank on a graph specially designed for a particular NLP task. For keyphrase extraction, it builds a graph using some set of text units as vertices. Edges are based on some measure of semantic or lexical similarity between the text unit vertices. Unlike PageRank, the edges are typically undirected and can be weighted to reflect a degree of similarity. Once the graph is constructed, it is used to form a stochastic matrix, combined with a damping factor (as in the "random surfer model"), and the ranking over vertices is obtained by finding the eigenvector corresponding to eigenvalue 1 (i.e., the stationary distribution of the random walk on the graph).
#
# The vertices should correspond to what we want to rank. Potentially, we could do something similar to the supervised methods and create a vertex for each unigram, bigram, trigram, etc. However, to keep the graph small, the authors decide to rank individual unigrams in a first step, and then include a second step that merges highly ranked adjacent unigrams to form multi-word phrases. This has a nice side effect of allowing us to produce keyphrases of arbitrary length. For example, if we rank unigrams and find that "advanced", "natural", "language", and "processing" all get high ranks, then we would look at the original text and see that these words appear consecutively and create a final keyphrase using all four together. Note that the unigrams placed in the graph can be filtered by part of speech. The authors found that adjectives and nouns were the best to include. Thus, some linguistic knowledge comes into play in this step.
#
# Edges are created based on word co-occurrence in this application of TextRank. Two vertices are connected by an edge if the unigrams appear within a window of size N in the original text. N is typically around 2–10. Thus, "natural" and "language" might be linked in a text about NLP. "Natural" and "processing" would also be linked because they would both appear in the same string of N words. These edges build on the notion of "text cohesion" and the idea that words that appear near each other are likely related in a meaningful way and "recommend" each other to the reader.
#
# Since this method simply ranks the individual vertices, we need a way to threshold or produce a limited number of keyphrases. The technique chosen is to set a count T to be a user-specified fraction of the total number of vertices in the graph. Then the top T vertices/unigrams are selected based on their stationary probabilities. A post- processing step is then applied to merge adjacent instances of these T unigrams. As a result, potentially more or less than T final keyphrases will be produced, but the number should be roughly proportional to the length of the original text.
#
# It is not initially clear why applying PageRank to a co-occurrence graph would produce useful keyphrases. One way to think about it is the following. A word that appears multiple times throughout a text may have many different co-occurring neighbors. For example, in a text about machine learning, the unigram "learning" might co-occur with "machine", "supervised", "un-supervised", and "semi-supervised" in four different sentences. Thus, the "learning" vertex would be a central "hub" that connects to these other modifying words. Running PageRank/TextRank on the graph is likely to rank "learning" highly. Similarly, if the text contains the phrase "supervised classification", then there would be an edge between "supervised" and "classification". If "classification" appears several other places and thus has many neighbors, its importance would contribute to the importance of "supervised". If it ends up with a high rank, it will be selected as one of the top T unigrams, along with "learning" and probably "classification". In the final post-processing step, we would then end up with keyphrases "supervised learning" and "supervised classification".
#
# In short, the co-occurrence graph will contain densely connected regions for terms that appear often and in different contexts. A random walk on this graph will have a stationary distribution that assigns large probabilities to the terms in the centers of the clusters. This is similar to densely connected Web pages getting ranked highly by PageRank. This approach has also been used in document summarization, considered below.
#
# Document summarization
# Like keyphrase extraction, document summarization aims to identify the essence of a text. The only real difference is that now we are dealing with larger text units—whole sentences instead of words and phrases.
#
# Before getting into the details of some summarization methods, we will mention how summarization systems are typically evaluated. The most common way is using the so-called ROUGE (Recall-Oriented Understudy for Gisting Evaluation) measure. This is a recall-based measure that determines how well a system-generated summary covers the content present in one or more human-generated model summaries known as references. It is recall-based to encourage systems to include all the important topics in the text. Recall can be computed with respect to unigram, bigram, trigram, or 4-gram matching. For example, ROUGE-1 is computed as division of count of unigrams in reference that appear in system and count of unigrams in reference summary.
#
# If there are multiple references, the ROUGE-1 scores are averaged. Because ROUGE is based only on content overlap, it can determine if the same general concepts are discussed between an automatic summary and a reference summary, but it cannot determine if the result is coherent or the sentences flow together in a sensible manner. High-order n-gram ROUGE measures try to judge fluency to some degree. Note that ROUGE is similar to the BLEU measure for machine translation, but BLEU is precision- based, because translation systems favor accuracy.
#
# A promising line in document summarization is adaptive document/text summarization.[8] The idea of adaptive summarization involves preliminary recognition of document/text genre and subsequent application of summarization algorithms optimized for this genre. First summarizes that perform adaptive summarization have been created.[9]
#
# Supervised learning approaches
# Supervised text summarization is very much like supervised keyphrase extraction. Basically, if you have a collection of documents and human-generated summaries for them, you can learn features of sentences that make them good candidates for inclusion in the summary. Features might include the position in the document (i.e., the first few sentences are probably important), the number of words in the sentence, etc. The main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary". This is not typically how people create summaries, so simply using journal abstracts or existing summaries is usually not sufficient. The sentences in these summaries do not necessarily match up with sentences in the original text, so it would be difficult to assign labels to examples for training. Note, however, that these natural summaries can still be used for evaluation purposes, since ROUGE-1 only cares about unigrams.
#
# Maximum entropy-based summarization
# During the DUC 2001 and 2002 evaluation workshops, TNO developed a sentence extraction system for multi-document summarization in the news domain. The system was based on a hybrid system using a naive Bayes classifier and statistical language models for modeling salience. Although the system exhibited good results, the researchers wanted to explore the effectiveness of a maximum entropy (ME) classifier for the meeting summarization task, as ME is known to be robust against feature dependencies. Maximum entropy has also been applied successfully for summarization in the broadcast news domain.
#
# TextRank and LexRank
# The unsupervised approach to summarization is also quite similar in spirit to unsupervised keyphrase extraction and gets around the issue of costly training data. Some unsupervised summarization approaches are based on finding a "centroid" sentence, which is the mean word vector of all the sentences in the document. Then the sentences can be ranked with regard to their similarity to this centroid sentence.
#
# A more principled way to estimate sentence importance is using random walks and eigenvector centrality. LexRank[10] is an algorithm essentially identical to TextRank, and both use this approach for document summarization. The two methods were developed by different groups at the same time, and LexRank simply focused on summarization, but could just as easily be used for keyphrase extraction or any other NLP ranking task.
#
# In both LexRank and TextRank, a graph is constructed by creating a vertex for each sentence in the document.
#
# The edges between sentences are based on some form of semantic similarity or content overlap. While LexRank uses cosine similarity of TF-IDF vectors, TextRank uses a very similar measure based on the number of words two sentences have in common (normalized by the sentences' lengths). The LexRank paper explored using unweighted edges after applying a threshold to the cosine values, but also experimented with using edges with weights equal to the similarity score. TextRank uses continuous similarity scores as weights.
#
# In both algorithms, the sentences are ranked by applying PageRank to the resulting graph. A summary is formed by combining the top ranking sentences, using a threshold or length cutoff to limit the size of the summary.
#
# It is worth noting that TextRank was applied to summarization exactly as described here, while LexRank was used as part of a larger summarization system (MEAD) that combines the LexRank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights. In this case, some training documents might be needed, though the TextRank results show the additional features are not absolutely necessary.
#
# Another important distinction is that TextRank was used for single document summarization, while LexRank has been applied to multi-document summarization. The task remains the same in both cases—only the number of sentences to choose from has grown. However, when summarizing multiple documents, there is a greater risk of selecting duplicate or highly redundant sentences to place in the same summary. Imagine you have a cluster of news articles on a particular event, and you want to produce one summary. Each article is likely to have many similar sentences, and you would only want to include distinct ideas in the summary. To address this issue, LexRank applies a heuristic post-processing step that builds up a summary by adding sentences in rank order, but discards any sentences that are too similar to ones already placed in the summary. The method used is called Cross-Sentence Information Subsumption (CSIS).
#
# These methods work based on the idea that sentences "recommend" other similar sentences to the reader. Thus, if one sentence is very similar to many others, it will likely be a sentence of great importance. The importance of this sentence also stems from the importance of the sentences "recommending" it. Thus, to get ranked highly and placed in a summary, a sentence must be similar to many sentences that are in turn also similar to many other sentences. This makes intuitive sense and allows the algorithms to be applied to any arbitrary new text. The methods are domain-independent and easily portable. One could imagine the features indicating important sentences in the news domain might vary considerably from the biomedical domain. However, the unsupervised "recommendation"-based approach applies to any domain.
#
# Multi-document summarization
# Main article: Multi-document summarization
# Multi-document summarization is an automatic procedure aimed at extraction of information from multiple texts written about the same topic. Resulting summary report allows individual users, such as professional information consumers, to quickly familiarize themselves with information contained in a large cluster of documents. In such a way, multi-document summarization systems are complementing the news aggregators performing the next step down the road of coping with information overload. Multi-document summarization may also be done in response to a question.[11]
#
# Multi-document summarization creates information reports that are both concise and comprehensive. With different opinions being put together and outlined, every topic is described from multiple perspectives within a single document. While the goal of a brief summary is to simplify information search and cut the time by pointing to the most relevant source documents, comprehensive multi-document summary should itself contain the required information, hence limiting the need for accessing original files to cases when refinement is required. Automatic summaries present information extracted from multiple sources algorithmically, without any editorial touch or subjective human intervention, thus making it completely unbiased.[dubious – discuss]
#
# Incorporating diversity
# Multi-document extractive summarization faces a problem of potential redundancy. Ideally, we would like to extract sentences that are both "central" (i.e., contain the main ideas) and "diverse" (i.e., they differ from one another). LexRank deals with diversity as a heuristic final stage using CSIS, and other systems have used similar methods, such as Maximal Marginal Relevance (MMR),[12] in trying to eliminate redundancy in information retrieval results. There is a general purpose graph-based ranking algorithm like Page/Lex/TextRank that handles both "centrality" and "diversity" in a unified mathematical framework based on absorbing Markov chain random walks. (An absorbing random walk is like a standard random walk, except some states are now absorbing states that act as "black holes" that cause the walk to end abruptly at that state.) The algorithm is called GRASSHOPPER.[13] In addition to explicitly promoting diversity during the ranking process, GRASSHOPPER incorporates a prior ranking (based on sentence position in the case of summarization).
#
# The state of the art results for multi-document summarization, however, are obtained using mixtures of submodular functions. These methods have achieved the state of the art results for Document Summarization Corpora, DUC 04 - 07.[14] Similar results were also achieved with the use of determinantal point processes (which are a special case of submodular functions) for DUC-04.[15]
#
# A new method for multi-lingual multi-document summarization that avoids redundancy works by simplifying and generating ideograms that represent the meaning of each sentence in each document and then evaluates similarity "qualitatively" by comparing the shape and position of said ideograms has recently been developed. This tool does not use word frequency, does not need training or preprocessing of any kind and works by generating ideograms that represent the meaning of each sentence and then summarizes using two user-supplied parameters: equivalence (when are two sentences to be considered equivalent) and relevance (how long is the desired summary).
#
# Submodular functions as generic tools for summarization
# The idea of a submodular set function has recently emerged as a powerful modeling tool for various summarization problems. Submodular functions naturally model notions of coverage, information, representation and diversity. Moreover, several important combinatorial optimization problems occur as special instances of submodular optimization. For example, the set cover problem is a special case of submodular optimization, since the set cover function is submodular. The set cover function attempts to find a subset of objects which cover a given set of concepts. For example, in document summarization, one would like the summary to cover all important and relevant concepts in the document. This is an instance of set cover. Similarly, the facility location problem is a special case of submodular functions. The Facility Location function also naturally models coverage and diversity. Another example of a submodular optimization problem is using a determinantal point process to model diversity. Similarly, the Maximum-Marginal-Relevance procedure can also be seen as an instance of submodular optimization. All these important models encouraging coverage, diversity and information are all submodular. Moreover, submodular functions can be efficiently combined together, and the resulting function is still submodular. Hence, one could combine one submodular function which models diversity, another one which models coverage and use human supervision to learn a right model of a submodular function for the problem.
#
# While submodular functions are fitting problems for summarization, they also admit very efficient algorithms for optimization. For example, a simple greedy algorithm admits a constant factor guarantee.[16] Moreover, the greedy algorithm is extremely simple to implement and can scale to large datasets, which is very important for summarization problems.
#
# Submodular functions have achieved state-of-the-art for almost all summarization problems. For example, work by Lin and Bilmes, 2012[17] shows that submodular functions achieve the best results to date on DUC-04, DUC-05, DUC-06 and DUC-07 systems for document summarization. Similarly, work by Lin and Bilmes, 2011,[18] shows that many existing systems for automatic summarization are instances of submodular functions. This was a breakthrough result establishing submodular functions as the right models for summarization problems.[citation needed]
#
# Submodular Functions have also been used for other summarization tasks. Tschiatschek et al., 2014 show[19] that mixtures of submodular functions achieve state-of-the-art results for image collection summarization. Similarly, Bairi et al., 2015[20] show the utility of submodular functions for summarizing multi-document topic hierarchies. Submodular Functions have also successfully been used for summarizing machine learning datasets.[21]
#
# Applications
# [icon]
# This section needs expansion. You can help by adding to it. (February 2017)
# Specific applications of automatic summarization include:
#
# The Reddit bot "autotldr",[22] created in 2011 summarizes news articles in the comment-section of reddit posts. It was found to be very useful by the reddit community which upvoted its summaries hundreds of thousands of times.[23] The name is reference to TL;DR − Internet slang for "too long; didn't read".[24][25]
# Evaluation techniques
# The most common way to evaluate the informativeness of automatic summaries is to compare them with human-made model summaries.
#
# Evaluation techniques fall into intrinsic and extrinsic,[26] inter-textual and intra-textual.[27]
#
# Intrinsic and extrinsic evaluation
# An intrinsic evaluation tests the summarization system in and of itself while an extrinsic evaluation tests the summarization based on how it affects the completion of some other task. Intrinsic evaluations have assessed mainly the coherence and informativeness of summaries. Extrinsic evaluations, on the other hand, have tested the impact of summarization on tasks like relevance assessment, reading comprehension, etc.
#
# Inter-textual and intra-textual
# Intra-textual methods assess the output of a specific summarization system, and the inter-textual ones focus on contrastive analysis of outputs of several summarization systems.
#
# Human judgement often has wide variance on what is considered a "good" summary, which means that making the evaluation process automatic is particularly difficult. Manual evaluation can be used, but this is both time and labor-intensive as it requires humans to read not only the summaries but also the source documents. Other issues are those concerning coherence and coverage.
#
# One of the metrics used in NIST's annual Document Understanding Conferences, in which research groups submit their systems for both summarization and translation tasks, is the ROUGE metric (Recall-Oriented Understudy for Gisting Evaluation [2]). It essentially calculates n-gram overlaps between automatically generated summaries and previously-written human summaries. A high level of overlap should indicate a high level of shared concepts between the two summaries. Note that overlap metrics like this are unable to provide any feedback on a summary's coherence. Anaphor resolution remains another problem yet to be fully solved. Similarly, for image summarization, Tschiatschek et al., developed a Visual-ROUGE score which judges the performance of algorithms for image summarization.[28]
#
# Domain specific versus domain independent summarization techniques
# Domain independent summarization techniques generally apply sets of general features which can be used to identify information-rich text segments. Recent research focus has drifted to domain-specific summarization techniques that utilize the available knowledge specific to the domain of text. For example, automatic summarization research on medical text generally attempts to utilize the various sources of codified medical knowledge and ontologies.[29]
#
# Evaluating summaries qualitatively
# The main drawback of the evaluation systems existing so far is that we need at least one reference summary, and for some methods more than one, to be able to compare automatic summaries with models. This is a hard and expensive task. Much effort has to be done in order to have corpus of texts and their corresponding summaries. Furthermore, for some methods, not only do we need to have human-made summaries available for comparison, but also manual annotation has to be performed in some of them (e.g. SCU in the Pyramid Method). In any case, what the evaluation methods need as an input, is a set of summaries to serve as gold standards and a set of automatic summaries. Moreover, they all perform a quantitative evaluation with regard to different similarity metrics.

# %%
print(summary)
# Out:
# Similar results were also achieved with the use of determinantal point processes (which are a special case of submodular functions) for DUC-04.[15]
#
# A new method for multi-lingual multi-document summarization that avoids redundancy works by simplifying and generating ideograms that represent the meaning of each sentence in each document and then evaluates similarity "qualitatively" by comparing the shape and position of said ideograms has recently been developed. They can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.
#
#  The main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary". Maximum entropy-based summarization
# During the DUC 2001 and 2002 evaluation workshops, TNO developed a sentence extraction system for multi-document summarization in the news domain. It is worth noting that TextRank was applied to summarization exactly as described here, while LexRank was used as part of a larger summarization system (MEAD) that combines the LexRank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights. Inter-textual and intra-textual
# Intra-textual methods assess the output of a specific summarization system, and the inter-textual ones focus on contrastive analysis of outputs of several summarization systems.
#
#  Another important distinction is that TextRank was used for single document summarization, while LexRank has been applied to multi-document summarization. An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document. The idea of adaptive summarization involves preliminary recognition of document/text genre and subsequent application of summarization algorithms optimized for this genre. Automatic summarization is the process of shortening a set of data computationally, to create a subset (a summary) that represents the most important or relevant information within the original content.
#
#  For text, extraction is analogous to the process of skimming, where the summary (if available), headings and subheadings, figures, the first and last paragraphs of a section, and optionally the first and last sentences in a paragraph are read before one chooses to read the entire document in detail.[3]
#
#  Some techniques and algorithms which naturally model summarization problems are TextRank and PageRank, Submodular set function, Determinantal point process, maximal marginal relevance (MMR) etc.
#
#  For example, in document summarization, one would like the summary to cover all important and relevant concepts in the document. Instead of trying to learn explicit features that characterize keyphrases, the TextRank algorithm[7] exploits the structure of the text itself to determine keyphrases that appear "central" to the text in the same way that PageRank selects important Web pages. At a very high level, summarization algorithms try to find subsets of objects (like set of sentences, or a set of images), which cover information of the entire set. For example, automatic summarization research on medical text generally attempts to utilize the various sources of codified medical knowledge and ontologies.[29]
#
#  An intrinsic evaluation tests the summarization system in and of itself while an extrinsic evaluation tests the summarization based on how it affects the completion of some other task. The two methods were developed by different groups at the same time, and LexRank simply focused on summarization, but could just as easily be used for keyphrase extraction or any other NLP ranking task.
#
#  Text summarization finds the most informative sentences in a document[1]; image summarization finds the most representative images within an image The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query. In addition to explicitly promoting diversity during the ranking process, GRASSHOPPER incorporates a prior ranking (based on sentence position in the case of summarization).
#
#  While the goal of a brief summary is to simplify information search and cut the time by pointing to the most relevant source documents, comprehensive multi-document summary should itself contain the required information, hence limiting the need for accessing original files to cases when refinement is required. For example, work by Lin and Bilmes, 2012[17] shows that submodular functions achieve the best results to date on DUC-04, DUC-05, DUC-06 and DUC-07 systems for document summarization. This tool does not use word frequency, does not need training or preprocessing of any kind and works by generating ideograms that represent the meaning of each sentence and then summarizes using two user-supplied parameters: equivalence (when are two sentences to be considered equivalent) and relevance (how long is the desired summary).
#
#  Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.
#
#  Some unsupervised summarization approaches are based on finding a "centroid" sentence, which is the mean word vector of all the sentences in the document. A promising line in document summarization is adaptive document/text summarization.[8] Like keyphrase extraction, document summarization aims to identify the essence of a text. Image collection summarization is another application example of automatic summarization. For example, in a text about machine learning, the unigram "learning" might co-occur with "machine", "supervised", "un-supervised", and "semi-supervised" in four different sentences. Before getting into the details of some summarization methods, we will mention how summarization systems are typically evaluated. In such a way, multi-document summarization systems are complementing the news aggregators performing the next step down the road of coping with information overload. In this way, TextRank does not rely on any previous training data at all, but rather can be run on any arbitrary piece of text, and it can produce output simply based on the text's intrinsic properties. To address this issue, LexRank applies a heuristic post-processing step that builds up a summary by adding sentences in rank order, but discards any sentences that are too similar to ones already placed in the summary. Multi-document summarization is an automatic procedure aimed at extraction of information from multiple texts written about the same topic. Recent research focus has drifted to domain-specific summarization techniques that utilize the available knowledge specific to the domain of text. Similarly, for image summarization, Tschiatschek et al., developed a Visual-ROUGE score which judges the performance of algorithms for image summarization.[28]
#
#  Hence, one could combine one submodular function which models diversity, another one which models coverage and use human supervision to learn a right model of a submodular function for the problem.
#
#  Supervised text summarization is very much like supervised keyphrase extraction. Domain independent summarization techniques generally apply sets of general features which can be used to identify information-rich text segments. This was a breakthrough result establishing submodular functions as the right models for summarization problems.[citation needed]
#
#  Because ROUGE is based only on content overlap, it can determine if the same general concepts are discussed between an automatic summary and a reference summary, but it cannot determine if the result is coherent or the sentences flow together in a sensible manner. The state of the art results for multi-document summarization, however, are obtained using mixtures of submodular functions. This approach has also been used in document summarization, considered below.
#
#  Multi-document summarization may also be done in response to a question.[11]
#
#  Examples of extracted content include key-phrases that can be used to "tag" or index a text document, or key sentences (including headings) that collectively comprise an abstract, and representative images or video segments, as stated above. Moreover, the greedy algorithm is extremely simple to implement and can scale to large datasets, which is very important for summarization problems.
#
#  Matches between the proposed keyphrases and the known keyphrases can be checked after stemming or applying some other text normalization.
#
#  For example, ROUGE-1 is computed as division of count of unigrams in reference that appear in system and count of unigrams in reference summary.
#
#  The sentences in these summaries do not necessarily match up with sentences in the original text, so it would be difficult to assign labels to examples for training. The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.). There are two general approaches to automatic summarization: extraction and abstraction.
#
#  There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on. While LexRank uses cosine similarity of TF-IDF vectors, TextRank uses a very similar measure based on the number of words two sentences have in common (normalized by the sentences' lengths). Maximum entropy has also been applied successfully for summarization in the broadcast news domain.
#
#  A summary is formed by combining the top ranking sentences, using a threshold or length cutoff to limit the size of the summary.
#
#  Given a document, we construct an example for each unigram, bigram, and trigram found in the text (though other text units are also possible, as discussed below). Such transformation, however, is computationally much more challenging than extraction, involving both natural language processing and often a deep understanding of the domain of the original text in cases where the original document relates to a special field of knowledge. "Paraphrasing" is even more difficult to apply to image and video, which is why most summarization systems are extractive.
#
#  As a result, potentially more or less than T final keyphrases will be produced, but the number should be roughly proportional to the length of the original text.
#
#  Extrinsic evaluations, on the other hand, have tested the impact of summarization on tasks like relevance assessment, reading comprehension, etc.
#
#  collection[citation needed]; video summarization extracts the most important frames from the video content.[2]
#
#  LexRank[10] is an algorithm essentially identical to TextRank, and both use this approach for document summarization. For example, if we rank unigrams and find that "advanced", "natural", "language", and "processing" all get high ranks, then we would look at the original text and see that these words appear consecutively and create a final keyphrase using all four together. Query based summarization techniques, additionally model for relevance of the summary with the query. Once the graph is constructed, it is used to form a stochastic matrix, combined with a damping factor (as in the "random surfer model"), and the ranking over vertices is obtained by finding the eigenvector corresponding to eigenvalue 1 (i.e., the stationary distribution of the random walk on the graph).
#
#  The unsupervised approach to summarization is also quite similar in spirit to unsupervised keyphrase extraction and gets around the issue of costly training data. This is a recall-based measure that determines how well a system-generated summary covers the content present in one or more human-generated model summaries known as references. Similarly, work by Lin and Bilmes, 2011,[18] shows that many existing systems for automatic summarization are instances of submodular functions. The only real difference is that now we are dealing with larger text units—whole sentences instead of words and phrases.
#
#  In contrast, an abstractive keyphrase system would somehow internalize the content and generate keyphrases that do not appear in the text, but more closely resemble what a human might produce, such as "political negligence" or "inadequate protection from floods". Specific applications of automatic summarization include:
#
#  Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.
#
#  These edges build on the notion of "text cohesion" and the idea that words that appear near each other are likely related in a meaningful way and "recommend" each other to the reader.
#
#  Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic). Tschiatschek et al., 2014 show[19] that mixtures of submodular functions achieve state-of-the-art results for image collection summarization. In the final post-processing step, we would then end up with keyphrases "supervised learning" and "supervised classification".
#
#  The most common way to evaluate the informativeness of automatic summaries is to compare them with human-made model summaries.
#
#  In both LexRank and TextRank, a graph is constructed by creating a vertex for each sentence in the document.
#
#  Incorporating diversity
# Multi-document extractive summarization faces a problem of potential redundancy. Basically, if you have a collection of documents and human-generated summaries for them, you can learn features of sentences that make them good candidates for inclusion in the summary. For example, the set cover problem is a special case of submodular optimization, since the set cover function is submodular. There is a general purpose graph-based ranking algorithm like Page/Lex/TextRank that handles both "centrality" and "diversity" in a unified mathematical framework based on absorbing Markov chain random walks. Thus, to get ranked highly and placed in a summary, a sentence must be similar to many sentences that are in turn also similar to many other sentences.
# Automatic summarization
# From Wikipedia, the free encyclopedia
# Jump to navigationJump to search
#
#  Multi-document summarization creates information reports that are both concise and comprehensive. The idea of a submodular set function has recently emerged as a powerful modeling tool for various summarization problems. First summarizes that perform adaptive summarization have been created.[9]
#
#  In any case, what the evaluation methods need as an input, is a set of summaries to serve as gold standards and a set of automatic summaries. Although the system exhibited good results, the researchers wanted to explore the effectiveness of a maximum entropy (ME) classifier for the meeting summarization task, as ME is known to be robust against feature dependencies.
